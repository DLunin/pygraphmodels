# %%
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.pyplot as plt
import networkx as nx
import pandas as pd
import sys
sys.path.append('/home/wrwt/Programming/pygraphmodels')
import graphmodels as gm
from itertools import permutations
from graphmodels import MatrixGraph, DGM
# %matplotlib inline
# %load_ext line_profiler
# Out:
# The line_profiler extension is already loaded. To reload it, use:
#   %reload_ext line_profiler

# %%
from graphmodels import AddEdge, RemoveEdge, ReverseEdge, InvalidOperation, GreedySearch, ScoreBIC
import heapq
class HeapGreedySearch:
    def __init__(self, data, cls_score):
        graph = nx.DiGraph()
        graph.add_nodes_from(data.columns)
        graph = MatrixGraph.from_networkx_DiGraph(graph, order=data.columns)
        self.graph = graph
        self.fscore = cls_score(graph, data)

        self.ops = []
        self.ops += [AddEdge(graph, self.fscore, u, v) for u, v in permutations(graph.nodes(), 2)]
        self.ops += [RemoveEdge(graph, self.fscore, u, v) for u, v in permutations(graph.nodes(), 2)]
        self.ops += [ReverseEdge(graph, self.fscore, u, v) for u, v in permutations(graph.nodes(), 2)]
        
        self.op_heap = [(-op.score(), op) for op in self.ops]
        heapq.heapify(self.op_heap)
            
    def iteration(self):
        while len(self.op_heap) > 0:
            op = heapq.heappop(self.op_heap)[1]
            if op.score() <= 1e-5:
                return True
            try:
                op.do()
                
                self.op_heap = [(-oper.score(), oper) for oper in self.ops]
                heapq.heapify(self.op_heap)
                
                op.score()
                return False
            except InvalidOperation:
                pass
        return True

    def __call__(self, max_iter=40, verbose=True):
        counter = 0
        while not self.iteration() and counter < max_iter:
            if verbose:
                print(self.fscore.total())
            counter += 1
        return DGM(self.graph.to_networkx_DiGraph())

# %%
from os import listdir
import os.path
NETWORKS_PATH = '/home/wrwt/Programming/pygraphmodels/networks/'
network_filenames = listdir(NETWORKS_PATH)
true_dgm = gm.DGM.read(os.path.join(NETWORKS_PATH, 'alarm.bif'))
true_dgm.draw()
# Out:
# <style>
#
# table
# {
#   border-collapse: collapse;
# }
# th
# {
#   color: #ffffff;
#   background-color: #000000;
# }
# td
# {
#   background-color: #cccccc;
# }
# table, th, td
# {
#   font-family:Arial, Helvetica, sans-serif;
#   border: 1px solid black;
#   text-align: center;
#   padding: 3px;
#   font-size:11pt;
# }
# g.mpld3-xaxis, g.mpld3-yaxis {
#     display: none;
# }
#
# </style>
#
# <div id="fig_el56531404579866155047313215434"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#     mpld3.register_plugin("htmltooltip", HtmlTooltipPlugin);
#     HtmlTooltipPlugin.prototype = Object.create(mpld3.Plugin.prototype);
#     HtmlTooltipPlugin.prototype.constructor = HtmlTooltipPlugin;
#     HtmlTooltipPlugin.prototype.requiredProps = ["id"];
#     HtmlTooltipPlugin.prototype.defaultProps = {labels:null, hoffset:0, voffset:10};
#     function HtmlTooltipPlugin(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     HtmlTooltipPlugin.prototype.draw = function(){
#        var obj = mpld3.get_element(this.props.id);
#        var labels = this.props.labels;
#        var tooltip = d3.select("body").append("div")
#                     .attr("class", "mpld3-tooltip")
#                     .style("position", "absolute")
#                     .style("z-index", "10")
#                     .style("visibility", "hidden");
#
#        obj.elements()
#            .on("mouseover", function(d, i){
#                               tooltip.html(labels[i])
#                                      .style("visibility", "visible");})
#            .on("mousemove", function(d, i){
#                     tooltip
#                       .style("top", d3.event.pageY + this.props.voffset + "px")
#                       .style("left",d3.event.pageX + this.props.hoffset + "px");
#                  }.bind(this))
#            .on("mouseout",  function(d, i){
#                            tooltip.style("visibility", "hidden");});
#     };
#
#        mpld3.draw_figure("fig_el56531404579866155047313215434", {"axes": [{"xlim": [-0.080000000000000002, 1.0800000000000001], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "PAP", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.19635541695968506, 0.11054902194080238], "rotation": -0.0, "id": "el5653140457982341008"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "VENTLUNG", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.50135378346023629, 0.42004234877900221], "rotation": -0.0, "id": "el5653140457982399568"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "SAO2", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.081561758970404102, 0.52013462871316207], "rotation": -0.0, "id": "el5653140457982400656"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "EXPCO2", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.54566482095666213, 0.31497969512027635], "rotation": -0.0, "id": "el5653140457982401744"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "HR", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.35910329707220889, 0.62172608947043595], "rotation": -0.0, "id": "el5653140457982435664"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "HREKG", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.41423822611937061, 0.22733644453744664], "rotation": -0.0, "id": "el5653140457982436752"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "CVP", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.54233101762601277, 0.74084351837610085], "rotation": -0.0, "id": "el5653140457982437840"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "KINKEDTUBE", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.17418016541258213, 0.83810280291895145], "rotation": -0.0, "id": "el5653140457982438928"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "BP", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.59386292704275745, 0.62107135120162227], "rotation": -0.0, "id": "el5653140457982493328"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "ERRCAUTER", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.32966527899553189, 0.04190051458818865], "rotation": -0.0, "id": "el5653140457982494416"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "PULMEMBOLUS", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.0, 0.34076141008862065], "rotation": -0.0, "id": "el5653140457982495504"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "SHUNT", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.26454866440449759, 0.31786234371614686], "rotation": -0.0, "id": "el5653140457982496592"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "MINVOLSET", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.47416679637305048, 0.0], "rotation": -0.0, "id": "el5653140457982014416"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "CATECHOL", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.65224331882295039, 0.46668819032578124], "rotation": -0.0, "id": "el5653140457982015504"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "ERRLOWOUTPUT", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.49728159786694048, 0.8536028040988124], "rotation": -0.0, "id": "e ...

# %%
data = true_dgm.rvs(size=100000)

# %%
# %%time
gs = GreedySearch(data, ScoreBIC)
# %lprun -f ScoreBIC.__call__ res = gs(max_iter=100)
# Out:
# 60461.3743157
# 113181.798143
# 165348.619621
# 216695.329249
# 263558.412198
# 309078.133992
# 354328.497394
# 397750.879897
# 438197.057677
# 474756.984151
# 510140.222606
# 541718.71571
# 573060.53566
# 604829.905532
# 636002.767434
# 664618.701917
# 691007.838214
# 716111.984527
# 741094.380921
# 765885.824215
# 782851.784255
# 803082.167523
# 819738.102696
# 834512.315468
# 849123.841095
# 863551.042464
# 877775.535885
# 891273.596471
# 902786.812911
# 913678.106793
# 924459.791201
# 933672.942228
# 942003.845499
# 949109.839953
# 955386.516975
# 960935.707444
# 965335.024117
# 969393.976861
# 973278.506696
# 977138.130625
# 980500.741198
# 983518.789904
# 986463.083058
# 989134.151852
# 991278.298823
# 993369.185764
# 995213.261109
# 996667.897027
# 997729.614323
# 998775.801933
# 998990.538613
# 999186.410559
# 999314.712821
# 999406.816225
# 999477.505129
# 999525.895844
# CPU times: user 2min 40s, sys: 236 ms, total: 2min 41s
# Wall time: 2min 40s

# %%
gs = GreedySearch(data, ScoreBIC)

# %%
# %%time
gs(max_iter=100).draw()
# Out:
# 61063.689687
# 114174.871475
# 166496.506152
# 218103.593792
# 264898.632596
# 310563.505731
# 355471.789741
# 398705.793392
# 439179.153348
# 475870.068866
# 511571.937049
# 543266.155435
# 574793.082133
# 606048.465386
# 637190.969008
# 665622.301738
# 692091.385988
# 717665.911013
# 742895.008643
# 767884.080735
# 785108.630416
# 805200.64713
# 822016.684726
# 837087.09322
# 852131.648734
# 866626.12354
# 880807.179415
# 893929.489418
# 905628.14434
# 916733.669417
# 927542.620493
# 936937.136605
# 945274.966527
# 952245.391466
# 958422.169575
# 963898.977437
# 968159.699658
# 972307.005056
# 976282.362825
# 980211.402893
# 983703.482027
# 986698.692826
# 989563.330292
# 992303.919378
# 994510.030504
# 996609.618743
# 998496.319409
# 999934.240579
# 1001104.75809
# 1002120.57471
# 1002335.81498
# 1002532.54129
# 1002664.88768
# 1002756.99108
# 1002818.64799
# 1002867.74116
# CPU times: user 2min 7s, sys: 96 ms, total: 2min 7s
# Wall time: 2min 7s
# <style>
#
# table
# {
#   border-collapse: collapse;
# }
# th
# {
#   color: #ffffff;
#   background-color: #000000;
# }
# td
# {
#   background-color: #cccccc;
# }
# table, th, td
# {
#   font-family:Arial, Helvetica, sans-serif;
#   border: 1px solid black;
#   text-align: center;
#   padding: 3px;
#   font-size:11pt;
# }
# g.mpld3-xaxis, g.mpld3-yaxis {
#     display: none;
# }
#
# </style>
#
# <div id="fig_el40411404770512229922538879158"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#     mpld3.register_plugin("htmltooltip", HtmlTooltipPlugin);
#     HtmlTooltipPlugin.prototype = Object.create(mpld3.Plugin.prototype);
#     HtmlTooltipPlugin.prototype.constructor = HtmlTooltipPlugin;
#     HtmlTooltipPlugin.prototype.requiredProps = ["id"];
#     HtmlTooltipPlugin.prototype.defaultProps = {labels:null, hoffset:0, voffset:10};
#     function HtmlTooltipPlugin(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     HtmlTooltipPlugin.prototype.draw = function(){
#        var obj = mpld3.get_element(this.props.id);
#        var labels = this.props.labels;
#        var tooltip = d3.select("body").append("div")
#                     .attr("class", "mpld3-tooltip")
#                     .style("position", "absolute")
#                     .style("z-index", "10")
#                     .style("visibility", "hidden");
#
#        obj.elements()
#            .on("mouseover", function(d, i){
#                               tooltip.html(labels[i])
#                                      .style("visibility", "visible");})
#            .on("mousemove", function(d, i){
#                     tooltip
#                       .style("top", d3.event.pageY + this.props.voffset + "px")
#                       .style("left",d3.event.pageX + this.props.hoffset + "px");
#                  }.bind(this))
#            .on("mouseout",  function(d, i){
#                            tooltip.style("visibility", "hidden");});
#     };
#
#        mpld3.draw_figure("fig_el40411404770512229922538879158", {"axes": [{"xlim": [-0.080000000000000002, 1.0800000000000001], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "PAP", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.096047683006148188, 0.46145943776991177], "rotation": -0.0, "id": "el4041140476390214096"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "VENTLUNG", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.80902705931616503, 0.80109191714660577], "rotation": -0.0, "id": "el4041140476390215184"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "SAO2", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.31242312936702332, 0.30324227914548907], "rotation": -0.0, "id": "el4041140476390215248"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "SHUNT", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.59211500724710364, 0.30986932209649193], "rotation": -0.0, "id": "el4041140476390213200"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "HR", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.53271357277059472, 0.97890484655860777], "rotation": -0.0, "id": "el4041140476370428624"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "HREKG", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.33249685586007288, 0.96176671945652026], "rotation": -0.0, "id": "el4041140476370429712"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "CVP", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.56636664851653051, 0.79898473630234523], "rotation": -0.0, "id": "el4041140476370430800"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "KINKEDTUBE", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.23817265629367781, 0.73087020279907766], "rotation": -0.0, "id": "el4041140476370431888"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "BP", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.70581900773773665, 0.26637866227471235], "rotation": -0.0, "id": "el4041140476369953808"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "ERRCAUTER", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.0, 0.89215129972849105], "rotation": -0.0, "id": "el4041140476369954896"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "PULMEMBOLUS", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.12104851860052043, 0.10456474923442262], "rotation": -0.0, "id": "el4041140476369955984"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "EXPCO2", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.59998347255643958, 0.58818495104352675], "rotation": -0.0, "id": "el4041140476369998096"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "MINVOLSET", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.56409857239378203, 0.0095341289796294377], "rotation": -0.0, "id": "el4041140476369999184"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "CATECHOL", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.51345484536436858, 0.48949912190044437], "rotation": -0.0, "id": "el4041140476370000272"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "ERRLOWOUTPUT", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.21891272449707866, 0.089895385583303275], "rotat ...
