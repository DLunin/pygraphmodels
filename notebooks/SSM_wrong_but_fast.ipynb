# %%
# %%capture
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.pyplot as plt
import networkx as nx
import pandas as pd
import sys
sys.path.append('/home/wrwt/Programming/pygraphmodels')
import graphmodels as gm
from itertools import permutations
from graphmodels import MatrixGraph, DGM
# %matplotlib inline
# %load_ext line_profiler

# %%
x = np.random.randint(0, 2, size=10000)
y = np.random.randint(0, 2, size=10000)

# %%
df = pd.DataFrame(data={'x': x, 'y': y})

# %%
gm.information.discrete_entropy(df[['x']])
# Out:
# 0.69311980031016129

# %%
gm.information.discrete_entropy(df[['y']])
# Out:
# 0.69313660052267512

# %%
gm.information.discrete_entropy(df[['x', 'y']])
# Out:
# 1.3860802966472781

# %%
2 * -0.5 * np.log(0.5)
# Out:
# 0.69314718055994529

# %%
4 * -0.5 * np.log(0.5)
# Out:
# 1.3862943611198906

# %%
from os import listdir
import os.path
NETWORKS_PATH = '/home/wrwt/Programming/pygraphmodels/networks/'
network_filenames = listdir(NETWORKS_PATH)
true_dgm = gm.DGM.read(os.path.join(NETWORKS_PATH, 'earthquake.bif'))
true_dgm.draw()
# Out:
# <style>
#
# table
# {
#   border-collapse: collapse;
# }
# th
# {
#   color: #ffffff;
#   background-color: #000000;
# }
# td
# {
#   background-color: #cccccc;
# }
# table, th, td
# {
#   font-family:Arial, Helvetica, sans-serif;
#   border: 1px solid black;
#   text-align: center;
#   padding: 3px;
#   font-size:11pt;
# }
# g.mpld3-xaxis, g.mpld3-yaxis {
#     display: none;
# }
#
# </style>
#
# <div id="fig_el7582140210669320464184202827"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#     mpld3.register_plugin("htmltooltip", HtmlTooltipPlugin);
#     HtmlTooltipPlugin.prototype = Object.create(mpld3.Plugin.prototype);
#     HtmlTooltipPlugin.prototype.constructor = HtmlTooltipPlugin;
#     HtmlTooltipPlugin.prototype.requiredProps = ["id"];
#     HtmlTooltipPlugin.prototype.defaultProps = {labels:null, hoffset:0, voffset:10};
#     function HtmlTooltipPlugin(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     HtmlTooltipPlugin.prototype.draw = function(){
#        var obj = mpld3.get_element(this.props.id);
#        var labels = this.props.labels;
#        var tooltip = d3.select("body").append("div")
#                     .attr("class", "mpld3-tooltip")
#                     .style("position", "absolute")
#                     .style("z-index", "10")
#                     .style("visibility", "hidden");
#
#        obj.elements()
#            .on("mouseover", function(d, i){
#                               tooltip.html(labels[i])
#                                      .style("visibility", "visible");})
#            .on("mousemove", function(d, i){
#                     tooltip
#                       .style("top", d3.event.pageY + this.props.voffset + "px")
#                       .style("left",d3.event.pageX + this.props.hoffset + "px");
#                  }.bind(this))
#            .on("mouseout",  function(d, i){
#                            tooltip.style("visibility", "hidden");});
#     };
#
#        mpld3.draw_figure("fig_el7582140210669320464184202827", {"axes": [{"xlim": [-0.080000000000000002, 1.0800000000000001], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "Burglary", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.0, 0.4947378303113335], "rotation": -0.0, "id": "el7582140209962294544"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "MaryCalls", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [1.0, 0.023791467320799186], "rotation": -0.0, "id": "el7582140209962340688"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "Alarm", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.41844559439227297, 0.3247992674992361], "rotation": -0.0, "id": "el7582140209962341776"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "JohnCalls", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.60186179789958238, 0.69440408970055212], "rotation": -0.0, "id": "el7582140209962342864"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "Earthquake", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.32052330795749012, 0.0], "rotation": -0.0, "id": "el7582140209962343952"}], "zoomable": true, "images": [], "xdomain": [-0.080000000000000002, 1.0800000000000001], "ylim": [-0.080000000000000002, 0.77440408970055208], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"gridOn": false}, "fontsize": 10.0, "position": "bottom", "nticks": 8, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"gridOn": false}, "fontsize": 10.0, "position": "left", "nticks": 10, "tickvalues": null}], "lines": [{"color": "#808080", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.0, "data": "data01", "id": "el7582140209962595152"}, {"color": "#000000", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 0.5, "xindex": 0, "linewidth": 5.0, "data": "data02", "id": "el7582140209962595600"}, {"color": "#808080", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.0, "data": "data03", "id": "el7582140209962597264"}, {"color": "#000000", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 0.5, "xindex": 0, "linewidth": 5.0, "data": "data04", "id": "el7582140209962193424"}, {"color": "#808080", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.0, "data": "data05", "id": "el7582140209962195024"}, {"color": "#000000", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 0.5, "xindex": 0, "linewidth": 5.0, "data": "data06", "id": "el7582140209962196624"}, {"color": "#808080", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 1, "xindex": 0, "linewidth": 1.0, "data": "data07", "id": "el7582140209962239248"}, {"color": "#000000", "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 2, "alpha": 0.5, "xindex": 0, "linewidth": 5.0, "data": "data08", "id": "el7582140209962240848"}], "markers": [{"edgecolor": "#000000", "facecolor": "#D3D3D3", "edgewidth": 1, "yindex": 1, "coordinates": "data", "zorder": 2, "markerpath": [[[0.0, 10.0], [2.652031, 10.0], [5.195798707848534, 8.946336915882418], [7.0710678118654755, 7.0710678118654755], [8.946336915882418, 5.195798707848534], [10.0, 2.652031], [10.0, 0.0], [10.0, -2.652031], [8.946336915882418, -5.195798707848534], [7.0710678118654755, -7.0710678118654755], [5.195798707848534, -8.946336915882418], [2.652031, -10.0], [0.0, -10.0], [-2.652031, -10.0], [-5.195798707848534, -8.946336915882418], [-7.07106781186547 ...

# %%
data = true_dgm.rvs(size=100000)

# %%
gm.information.discrete_entropy(data[['Earthquake', 'Burglary', 'Alarm', 'MaryCalls']])
# Out:
# 0.23667459871510491

# %%
gm.information.discrete_entropy(data[['Earthquake', 'Burglary']])
# Out:
# 0.15085600437661084

# %%
gm.information.discrete_entropy(data[['Earthquake']]) + gm.information.discrete_entropy(data[['Burglary']])
# Out:
# 0.15086088859994315

# %%
from itertools import repeat
class SubsetGraph(nx.DiGraph):
    def __init__(self):
        nx.DiGraph.__init__(self)
        
    def add_subset(self, subs, f=None):
        subs = frozenset(subs)
        if subs in self.nodes():
            return 
        self.add_node(subs, f=f)
        for node in list(self.nodes()):
            if node > subs and all(not child > subs for child in self.successors(node)):
                self.add_edge(node, subs)
        
        for pa, ch in list(self.edges()):
            if subs < pa and ch < subs:
                self.remove_edge(pa, ch)
                self.add_edge(subs, ch)
        for ch in list(self.nodes()):
            if ch < subs and all(not parent <= subs for parent in self.predecessors(ch)):
                self.add_edge(subs, ch)
                
    def get_parents(self, subs):
        subs = frozenset(subs)
        if subs in self.nodes():
            return self.predecessors(subs)
        results = []
        for node in list(self.nodes()):
            if node > subs and all(not child > subs for child in self.successors(node)):
                results.append(node)
        return results
    
    def get_children(self, subs):
        subs = frozenset(subs)
        if subs in self.nodes():
            return self.successors(subs)
        results = set()
        for pa, ch in list(self.edges()):
            if subs < pa and ch < subs:
                results.add(ch)
        for ch in list(self.nodes()):
            if ch < subs and all(not parent <= subs for parent in self.predecessors(ch)):
                results.add(ch)
        return results
    
    def upper_bound(self, subs):
        #print 'calculating upper_bound of', subs
        subs = frozenset(subs)
        if subs in self.nodes():
            return self.node[subs]['f']
        estimates = []
        for ch in self.get_children(subs):
            estimates.append(self.node[ch]['f'] + self.upper_bound(subs - ch))
        return min(np.min(estimates), np.min(self.node[pa]['f'] for pa in self.get_parents(subs)))
    
    def lower_bound1(self, subs):
        #print 'calculating lower_bound of', subs
        subs = frozenset(subs)
        if subs in self.nodes():
            return self.node[subs]['f']
        estimates = [0]
        for ch in self.get_children(subs):
            estimates.append(max(self.node[ch]['f'], self.upper_bound(subs - ch)))
        return np.max(estimates)
    
    def lower_bound2(self, subs):
        #print 'calculating lower_bound of', subs
        subs = frozenset(subs)
        if subs in self.nodes():
            return self.node[subs]['f']
        estimates = [0]
        for pa in self.get_parents(subs):
            estimates.append(self.node[pa]['f'] - self.upper_bound(pa - subs))
        return np.max(estimates)
    
    def lower_bound(self, subs):
        return max(self.lower_bound1(subs), self.lower_bound2(subs))

# %%
from itertools import repeat
class OptimizedSubsetGraph(nx.DiGraph):
    def __init__(self):
        nx.DiGraph.__init__(self)
        
    def add_subset(self, subs, f=None):
        subs = frozenset(subs)
        if subs in self.nodes():
            return 
        self.add_node(subs, f=f)
        for node in list(self.nodes()):
            if node > subs and all(not child > subs for child in self.successors(node)):
                self.add_edge(node, subs)
        
        for pa, ch in list(self.edges()):
            if subs < pa and ch < subs:
                self.remove_edge(pa, ch)
                self.add_edge(subs, ch)
        for ch in list(self.nodes()):
            if ch < subs and all(not parent <= subs for parent in self.predecessors(ch)):
                self.add_edge(subs, ch)
                
    def get_parents(self, subs):
        subs = frozenset(subs)
        if subs in self.nodes():
            return self.predecessors(subs)
        results = []
        for node in list(self.nodes()):
            if node > subs and all(not child > subs for child in self.successors(node)):
                results.append(node)
        return results
    
    def get_children(self, subs):
        subs = frozenset(subs)
        if subs in self.nodes():
            return self.successors(subs)
        results = set()
        for pa, ch in list(self.edges()):
            if subs < pa and ch < subs:
                results.add(ch)
        for ch in list(self.nodes()):
            if ch < subs and all(not parent <= subs for parent in self.predecessors(ch)):
                results.add(ch)
        return results
    
    def upper_bound(self, subs):
        subs = frozenset(subs)
        if subs in self.nodes():
            return self.node[subs]['f']
        estimates = []
        for ch in self.get_children(subs):
            estimates.append(self.node[ch]['f'] + self.upper_bound(subs - ch))
        return min(np.min(estimates), np.min(self.node[pa]['f'] for pa in self.get_parents(subs)))
    
    def lower_bound1(self, subs):
        subs = frozenset(subs)
        if subs in self.nodes():
            return self.node[subs]['f']
        estimates = [0]
        for ch in self.get_children(subs):
            estimates.append(max(self.node[ch]['f'], self.upper_bound(subs - ch)))
        return np.max(estimates)
    
    def lower_bound2(self, subs):
        subs = frozenset(subs)
        if subs in self.nodes():
            return self.node[subs]['f']
        estimates = [0]
        for pa in self.get_parents(subs):
            estimates.append(self.node[pa]['f'] - self.upper_bound(pa - subs))
        return np.max(estimates)
    
    def lower_bound(self, subs):
        return max(self.lower_bound1(subs), self.lower_bound2(subs))

# %%
sg = SubsetGraph()
sg.add_subset([1], 0.5)
sg.add_subset([3, 4], 1.1)
sg.add_subset([1, 2], 0.7)
sg.add_subset([2], 0.5)
sg.add_subset([3], 0.3)
sg.add_subset([4], 1.0)
sg.add_subset([1, 2, 3], 0.9)
sg.add_subset([1, 2, 3, 4], 1.9)
sg.lower_bound([1, 3, 4]), sg.upper_bound([1, 3, 4])
# Out:
# (1.3999999999999999, 1.6000000000000001)

# %%
sg = SubsetGraph()
sg.add_subset([1], 0.3)
sg.add_subset([2], 0.4)
sg.add_subset([3], 0.5)
sg.add_subset([4], 0.6)
sg.add_subset([1, 2], 0.55)
sg.add_subset([2, 3], 0.7)
sg.add_subset([3, 4], 1.0)
sg.lower_bound([1, 4]), sg.upper_bound([1, 4])
# Out:
# (0.59999999999999998, 0.89999999999999991)

# %%
data = true_dgm.rvs(10000)

# %%
sg = SubsetGraph()
ee = gm.EntropyEstimator(gm.MatrixGraph.from_networkx_DiGraph(true_dgm, order=data.columns), data)

# %%
def add_subs(*subs):
    subs = frozenset(subs)
    f = ee([name in subs for name in data.columns])
    sg.add_subset(subs, f)

# %%
def entr(*subs):
    return ee([name in subs for name in data.columns])

# %%
def bounds(*subs):
    return sg.lower_bound(frozenset(subs)), sg.upper_bound(frozenset(subs))

# %%
for var in data.columns:
    add_subs(var)

# %%
add_subs('Burglary', 'Earthquake', 'MaryCalls', 'JohnCalls')

# %%
# %time entr('Burglary', 'MaryCalls')
# Out:
# CPU times: user 8 ms, sys: 0 ns, total: 8 ms
# Wall time: 6.55 ms
# 0.14251997579567946

# %%
bounds('Alarm', 'Burglary')
# Out:
# (0.081621758769409788, 0.14081568637746736)

# %%
bounds('Alarm', 'Earthquake')
# Out:
# (0.099204378331722909, 0.18082613710113271)

# %%
bounds('Alarm', 'Earthquake', 'MaryCalls')[1] - bounds('Alarm', 'Earthquake')[0]
# Out:
# 0.18275821452609031

# %%
bounds('Alarm', 'Earthquake', 'MaryCalls')[0] - bounds('Alarm', 'Earthquake')[1]
# Out:
# 0.019514696987270708

# %%
import numpy as np
from graphmodels.information import discrete_entropy


class EntropyEstimator:
    def __init__(self, graph, data):
        self.graph = graph
        self.data = data
        self.cache = {}

    def _footprint(self, nodes):
        return tuple(nodes)

    def __call__(self, nodes):
        fp = self._footprint(nodes)
        if fp in self.cache:
            return self.cache[fp]

        if np.any(nodes):
            subdata = self.data[self.data.columns[nodes]]
            result = discrete_entropy(subdata)
        else:
            result = 0

        self.cache[fp] = result
        return result


class InformationEstimator:
    def __init__(self, graph, data):
        self.graph = graph
        self.entropy_estimator = EntropyEstimator(graph, data)
        self.chosen = []

    def __call__(self, node, parents):
        parents = np.array(parents, dtype=bool)
        h1 = self.entropy_estimator(parents)
        temp = np.zeros(len(parents), dtype=bool)
        temp[node] = True
        h2 = self.entropy_estimator(temp)
        parents[node] = True
        h12 = self.entropy_estimator(parents)
        return h1 + h2 - h12


class ScoreBIC:
    def __init__(self, graph, data):
        self.graph = graph
        self.data = data
        self.n_values = np.asarray([len(self.data[column].value_counts()) for column in self.data.columns])
        self.mi_estimator = InformationEstimator(graph, data)

    def __call__(self, node, parents):
        parents = np.asarray(parents, dtype=bool)
        k = self.n_values[node]*np.prod(self.n_values[parents]) - 1
        n = self.data.shape[0]
        l = n*self.mi_estimator(node, parents)

        result = l - 0.5 * np.log(n) * k
        return result

    def total(self):
        score = 0.
        for node in self.graph.nodes():
            pa = self.graph.adj[:, node].copy()
            score += self(node, pa)
        return score

# %%
class AdvancedEntropyEstimator:
    def __init__(self, graph, data):
        self.graph = graph
        self.data = data
        self.sg = SubsetGraph()
        self._initialize_sg()
        self.cache = {}

    def _initialize_sg(self):
        vec = np.asarray([False] * len(self.data.columns), dtype=bool)
        for i, column in enumerate(self.data.columns):
            vec[i] = True
            self.__call__(vec)
            vec[i] = False
        
    def _key(self, subs):
        return frozenset([name for name, included in zip(data.columns, subs) if included])
    
    def _add_subs(self, subs, f):
        self.sg.add_subset(subs, f)
    
    def __call__(self, nodes):
        if not np.any(nodes):
            return 0
        key = self._key(nodes)
        if key in self.sg.nodes():
            return self.sg.node[key]['f']
        subdata = self.data[self.data.columns[nodes]]
        result = discrete_entropy(subdata)
        self._add_subs(key, f=result)
        return result
    
    def lower_bound(self, nodes):
        if not np.any(nodes):
            return 0
        key = self._key(nodes)
        return self.sg.lower_bound(key)
    
    def upper_bound(self, nodes):
        if not np.any(nodes):
            return 0
        key = self._key(nodes)
        return self.sg.upper_bound(key)
    
class AdvancedInformationEstimator:
    def __init__(self, graph, data):
        self.graph = graph
        self.entropy_estimator = AdvancedEntropyEstimator(graph, data)
        self.chosen = []

    def __call__(self, node, parents):
        parents = np.array(parents, dtype=bool)
        h1 = self.entropy_estimator(parents)
        temp = np.zeros(len(parents), dtype=bool)
        temp[node] = True
        h2 = self.entropy_estimator(temp)
        parents[node] = True
        h12 = self.entropy_estimator(parents)
        return h1 + h2 - h12
    
    def lower_bound(self, node, parents):
        parents = np.array(parents, dtype=bool)
        h1 = self.entropy_estimator.lower_bound(parents)
        temp = np.zeros(len(parents), dtype=bool)
        temp[node] = True
        h2 = self.entropy_estimator.lower_bound(temp)
        parents[node] = True
        h12 = self.entropy_estimator.upper_bound(parents)
        return h1 + h2 - h12
        
    def upper_bound(self, node, parents):
        parents = np.array(parents, dtype=bool)
        h1 = self.entropy_estimator.upper_bound(parents)
        temp = np.zeros(len(parents), dtype=bool)
        temp[node] = True
        h2 = self.entropy_estimator.upper_bound(temp)
        parents[node] = True
        h12 = self.entropy_estimator.lower_bound(parents)
        return h1 + h2 - h12
    
class AdvancedScoreBIC:
    def __init__(self, graph, data):
        self.graph = graph
        self.data = data
        self.n_values = np.asarray([len(self.data[column].value_counts()) for column in self.data.columns])
        self.mi_estimator = AdvancedInformationEstimator(graph, data)

    def __call__(self, node, parents, option=None):
        parents = np.asarray(parents, dtype=bool)
        k = self.n_values[node]*np.prod(self.n_values[parents]) - 1
        n = self.data.shape[0]
        
        if option == 'lower_bound':
            l = n*self.mi_estimator.lower_bound(node, parents)
        elif option == 'upper_bound':
            l = n*self.mi_estimator.upper_bound(node, parents)
        else:
            l = n*self.mi_estimator(node, parents)

        result = l - 0.5 * np.log(n) * k
        return result
    
    def lower_bound(self, node, parents):
        parents = np.asarray(parents, dtype=bool)
        k = self.n_values[node]*np.prod(self.n_values[parents]) - 1
        n = self.data.shape[0]
        l = n*self.mi_estimator.lower_bound(node, parents)

        result = l - 0.5 * np.log(n) * k
        return result

    def upper_bound(self, node, parents):
        parents = np.asarray(parents, dtype=bool)
        k = self.n_values[node]*np.prod(self.n_values[parents]) - 1
        n = self.data.shape[0]
        l = n*self.mi_estimator.upper_bound(node, parents)

        result = l - 0.5 * np.log(n) * k
        return result
    
    def total(self):
        score = 0.
        for node in self.graph.nodes():
            pa = self.graph.adj[:, node].copy()
            score += self(node, pa)
        return score

# %%
from graphmodels import LocalOperation

class AdvancedAddEdge(LocalOperation):
    def __init__(self, graph, fscore, src, dst):
        LocalOperation.__init__(self, graph, fscore)
        self.src = src
        self.dst = dst

    def do(self):
        if self.graph.adj[self.src, self.dst]:
            raise InvalidOperation()
        self.graph.adj[self.src, self.dst] = 1
        if not self.graph.is_acyclic():
            self.graph.adj[self.src, self.dst] = 0
            raise InvalidOperation()
        return self

    def undo(self):
        self.graph.adj[self.src, self.dst] = 0
        return self

    def score(self):
        pa = self.graph.adj[:, self.dst].copy()
        score = -self.fscore(self.dst, pa)
        pa[self.src] = 1
        score += self.fscore(self.dst, pa)
        return score
    
    def lower_bound(self):
        pa = self.graph.adj[:, self.dst].copy()
        score = -self.fscore.upper_bound(self.dst, pa)
        pa[self.src] = 1
        score += self.fscore.lower_bound(self.dst, pa)
        return score
    
    def upper_bound(self):
        pa = self.graph.adj[:, self.dst].copy()
        score = -self.fscore.lower_bound(self.dst, pa)
        pa[self.src] = 1
        score += self.fscore.upper_bound(self.dst, pa)
        return score
    


class AdvancedRemoveEdge(LocalOperation):
    def __init__(self, graph, fscore, src, dst):
        LocalOperation.__init__(self, graph, fscore)
        self.src = src
        self.dst = dst

    def do(self):
        if not self.graph.adj[self.src, self.dst]:
            raise InvalidOperation()
        self.graph.adj[self.src, self.dst] = 0
        return self

    def undo(self):
        self.graph.adj[self.src, self.dst] = 1
        return self

    def score(self):
        pa = self.graph.adj[:, self.dst].copy()
        score = -self.fscore(self.dst, pa)
        pa[self.src] = 0
        score += self.fscore(self.dst, pa)
        return score
    
    def lower_bound(self):
        pa = self.graph.adj[:, self.dst].copy()
        score = -self.fscore.upper_bound(self.dst, pa)
        pa[self.src] = 0
        score += self.fscore.lower_bound(self.dst, pa)
        return score

    def upper_bound(self):
        pa = self.graph.adj[:, self.dst].copy()
        score = -self.fscore.lower_bound(self.dst, pa)
        pa[self.src] = 0
        score += self.fscore.upper_bound(self.dst, pa)
        return score

class AdvancedReverseEdge(LocalOperation):
    def __init__(self, graph, fscore, src, dst):
        LocalOperation.__init__(self, graph, fscore)
        self.src = src
        self.dst = dst

    def do(self):
        if not self.graph.adj[self.src, self.dst]:
            raise InvalidOperation()
        self.graph.adj[self.src, self.dst] = 0
        self.graph.adj[self.dst, self.src] = 1
        if not self.graph.is_acyclic():
            self.graph.adj[self.src, self.dst] = 1
            self.graph.adj[self.dst, self.src] = 0
            raise InvalidOperation()
        return self

    def undo(self):
        self.graph.adj[self.src, self.dst] = 1
        self.graph.adj[self.dst, self.src] = 0
        return self

    def score(self):
        pa = self.graph.adj[:, self.dst].copy()
        score = -self.fscore(self.dst, pa)
        pa[self.src] = 0
        score += self.fscore(self.dst, pa)

        pa = self.graph.adj[:, self.src].copy()
        score -= self.fscore(self.src, pa)
        pa[self.dst] = 1
        score += self.fscore(self.src, pa)
        return score
    
    def lower_bound(self):
        pa = self.graph.adj[:, self.dst].copy()
        score = -self.fscore.upper_bound(self.dst, pa)
        pa[self.src] = 0
        score += self.fscore.lower_bound(self.dst, pa)

        pa = self.graph.adj[:, self.src].copy()
        score -= self.fscore.upper_bound(self.src, pa)
        pa[self.dst] = 1
        score += self.fscore.lower_bound(self.src, pa)
        return score
    
    def upper_bound(self):
        pa = self.graph.adj[:, self.dst].copy()
        score = -self.fscore.lower_bound(self.dst, pa)
        pa[self.src] = 0
        score += self.fscore.upper_bound(self.dst, pa)

        pa = self.graph.adj[:, self.src].copy()
        score -= self.fscore.lower_bound(self.src, pa)
        pa[self.dst] = 1
        score += self.fscore.upper_bound(self.src, pa)
        return score

# %%
from graphmodels import AddEdge, RemoveEdge, ReverseEdge, InvalidOperation
class AdvancedGreedySearch:
    def __init__(self, data, cls_score):
        graph = nx.DiGraph()
        graph.add_nodes_from(data.columns)
        graph = MatrixGraph.from_networkx_DiGraph(graph, order=data.columns)
        self.graph = graph
        self.fscore = cls_score(graph, data)

        self.ops = []
        self.ops += [AdvancedAddEdge(graph, self.fscore, u, v) for u, v in permutations(graph.nodes(), 2)]
        self.ops += [AdvancedRemoveEdge(graph, self.fscore, u, v) for u, v in permutations(graph.nodes(), 2)]
        self.ops += [AdvancedReverseEdge(graph, self.fscore, u, v) for u, v in permutations(graph.nodes(), 2)]
        
        self.ops = [[op, op.upper_bound()] for op in self.ops]

    def iteration(self):
        #ops.sort(reverse=True, key=lambda x: x[1] + x[2])
        
        best_op = None
        best_score = 0.
        
        skipped = 0
        
        for i in range(len(self.ops)):
            op = self.ops[i][0]
            ub = self.ops[i][1]
            
            if ub < best_score:
                skipped += 1
                continue
                
            self.ops[i][1] = self.ops[i][0].upper_bound()
            ub = self.ops[i][1]
            if ub < best_score:
                skipped += 1
                continue
                
            try:
                current_score = op.score()
                op.do()
                if current_score > best_score:
                    best_score = current_score
                    best_op = op
                op.undo()
            except InvalidOperation:
                pass
        
        print 'done {}, skippped {} operations out of {}'.format(len(self.ops) - skipped, skipped, len(self.ops))
        if best_op is None or best_op.score() < 1e-5:
            return True
        best_op.do()
        return False

    def __call__(self, max_iter=40, verbose=True):
        counter = 0
        while not self.iteration() and counter < max_iter:
            if verbose:
                print(self.fscore.total())
            counter += 1
        return DGM(self.graph.to_networkx_DiGraph())

# %%
from os import listdir
import os.path
NETWORKS_PATH = '/home/wrwt/Programming/pygraphmodels/networks/'
network_filenames = listdir(NETWORKS_PATH)
true_dgm = gm.DGM.read(os.path.join(NETWORKS_PATH, 'alarm.bif'))
true_dgm.draw()
# Out:
# <style>
#
# table
# {
#   border-collapse: collapse;
# }
# th
# {
#   color: #ffffff;
#   background-color: #000000;
# }
# td
# {
#   background-color: #cccccc;
# }
# table, th, td
# {
#   font-family:Arial, Helvetica, sans-serif;
#   border: 1px solid black;
#   text-align: center;
#   padding: 3px;
#   font-size:11pt;
# }
# g.mpld3-xaxis, g.mpld3-yaxis {
#     display: none;
# }
#
# </style>
#
# <div id="fig_el75821402099599736484503959062"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#     mpld3.register_plugin("htmltooltip", HtmlTooltipPlugin);
#     HtmlTooltipPlugin.prototype = Object.create(mpld3.Plugin.prototype);
#     HtmlTooltipPlugin.prototype.constructor = HtmlTooltipPlugin;
#     HtmlTooltipPlugin.prototype.requiredProps = ["id"];
#     HtmlTooltipPlugin.prototype.defaultProps = {labels:null, hoffset:0, voffset:10};
#     function HtmlTooltipPlugin(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     HtmlTooltipPlugin.prototype.draw = function(){
#        var obj = mpld3.get_element(this.props.id);
#        var labels = this.props.labels;
#        var tooltip = d3.select("body").append("div")
#                     .attr("class", "mpld3-tooltip")
#                     .style("position", "absolute")
#                     .style("z-index", "10")
#                     .style("visibility", "hidden");
#
#        obj.elements()
#            .on("mouseover", function(d, i){
#                               tooltip.html(labels[i])
#                                      .style("visibility", "visible");})
#            .on("mousemove", function(d, i){
#                     tooltip
#                       .style("top", d3.event.pageY + this.props.voffset + "px")
#                       .style("left",d3.event.pageX + this.props.hoffset + "px");
#                  }.bind(this))
#            .on("mouseout",  function(d, i){
#                            tooltip.style("visibility", "hidden");});
#     };
#
#        mpld3.draw_figure("fig_el75821402099599736484503959062", {"axes": [{"xlim": [-0.080000000000000002, 1.0618343774211363], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "PAP", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.48875476426898751, 0.9556822152386556], "rotation": -0.0, "id": "el7582140209957690576"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "VENTLUNG", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.14871177278885248, 0.70970897997108562], "rotation": -0.0, "id": "el7582140209957736720"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "SAO2", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.18181532685557061, 0.20253756269548187], "rotation": -0.0, "id": "el7582140209957737808"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "EXPCO2", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.39571829119986035, 0.39526608834639426], "rotation": -0.0, "id": "el7582140209957738896"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "HR", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.48315200413395332, 0.032224013875167677], "rotation": -0.0, "id": "el7582140209957739984"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "HREKG", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.51115112565109178, 0.48599398216310957], "rotation": -0.0, "id": "el7582140209957261904"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "CVP", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.92225525327127578, 0.66393040198453235], "rotation": -0.0, "id": "el7582140209957262992"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "KINKEDTUBE", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.090269990645932427, 0.56558569944268211], "rotation": -0.0, "id": "el7582140209957264080"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "BP", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.69332165547997138, 0.63911588035207956], "rotation": -0.0, "id": "el7582140209957265168"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "ERRCAUTER", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.35862493394482137, 1.0], "rotation": -0.0, "id": "el7582140209957311376"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "PULMEMBOLUS", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.18567896740498863, 0.80977483136802331], "rotation": -0.0, "id": "el7582140209957312464"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "SHUNT", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.11629138146909589, 0.55448130876221213], "rotation": -0.0, "id": "el7582140209957313552"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "MINVOLSET", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.66400484988391817, 0.068086723194556525], "rotation": -0.0, "id": "el7582140209957359760"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "CATECHOL", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.69179272474570508, 0.33979107354137594], "rotation": -0.0, "id": "el7582140209957360848"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "ERRLOWOUTPUT", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.53589554545196261, 0.0], "rotation": -0.0, "id":  ...

# %%
data = true_dgm.rvs(size=100000)

# %%
gs = AdvancedGreedySearch(data, AdvancedScoreBIC)

# %%
# %%time
gs(max_iter=100).draw()
# Out:
# done 313, skippped 3683 operations out of 3996
# 60889.7189542
# done 72, skippped 3924 operations out of 3996
# 113552.484436
# done 21, skippped 3975 operations out of 3996
# 165754.643595
# done 12, skippped 3984 operations out of 3996
# 216923.178485
# done 10, skippped 3986 operations out of 3996
# 263877.542988
# done 10, skippped 3986 operations out of 3996
# 309303.341879
# done 10, skippped 3986 operations out of 3996
# 354272.587448
# done 48, skippped 3948 operations out of 3996
# 397594.118765
# done 24, skippped 3972 operations out of 3996
# 437586.675578
# done 17, skippped 3979 operations out of 3996
# 473717.466177
# done 15, skippped 3981 operations out of 3996
# 509338.160077
# done 78, skippped 3918 operations out of 3996
# 541232.30433
# done 34, skippped 3962 operations out of 3996
# 572872.257958
# done 22, skippped 3974 operations out of 3996
# 604099.371962
# done 24, skippped 3972 operations out of 3996
# 632885.205033
# done 29, skippped 3967 operations out of 3996
# 659577.733541
# done 27, skippped 3969 operations out of 3996
# 684668.031339
# done 174, skippped 3822 operations out of 3996
# 715681.169215
# done 38, skippped 3958 operations out of 3996
# 737609.477311
# done 101, skippped 3895 operations out of 3996
# 755133.406801
# done 49, skippped 3947 operations out of 3996
# 771795.506098
# done 44, skippped 3952 operations out of 3996
# 786596.551872
# done 39, skippped 3957 operations out of 3996
# 801374.311483
# done 39, skippped 3957 operations out of 3996
# 815726.769127
# done 41, skippped 3955 operations out of 3996
# 829846.236007
# done 43, skippped 3953 operations out of 3996
# 843046.412624
# done 58, skippped 3938 operations out of 3996
# 868343.021263
# done 58, skippped 3938 operations out of 3996
# 879509.921338
# done 55, skippped 3941 operations out of 3996
# 890114.987532
# done 84, skippped 3912 operations out of 3996
# 900658.474941
# done 116, skippped 3880 operations out of 3996
# 908915.39602
# done 89, skippped 3907 operations out of 3996
# 915371.413076
# done 88, skippped 3908 operations out of 3996
# 921576.14675
# done 79, skippped 3917 operations out of 3996
# 930853.251243
# done 88, skippped 3908 operations out of 3996
# 936444.293511
# done 73, skippped 3923 operations out of 3996
# 944922.147547
# done 133, skippped 3863 operations out of 3996
# 949246.173905
# done 116, skippped 3880 operations out of 3996
# 953536.333722
# done 105, skippped 3891 operations out of 3996
# 957558.840967
# done 110, skippped 3886 operations out of 3996
# 961859.383846
# done 138, skippped 3858 operations out of 3996
# 964910.166623
# done 133, skippped 3863 operations out of 3996
# 967907.602332
# done 128, skippped 3868 operations out of 3996
# 970877.172006
# done 114, skippped 3882 operations out of 3996
# 974543.776787
# done 146, skippped 3850 operations out of 3996
# 977365.456192
# done 150, skippped 3846 operations out of 3996
# 979658.74418
# done 148, skippped 3848 operations out of 3996
# 981836.817926
# done 164, skippped 3832 operations out of 3996
# 983852.32006
# done 166, skippped 3830 operations out of 3996
# 985644.660173
# done 150, skippped 3846 operations out of 3996
# 987413.859765
# done 152, skippped 3844 operations out of 3996
# 989163.356627
# done 210, skippped 3786 operations out of 3996
# 990228.947051
# done 259, skippped 3737 operations out of 3996
# 990954.859103
# done 289, skippped 3707 operations out of 3996
# 991054.991403
# done 621, skippped 3375 operations out of 3996
# 991182.367443
# done 1112, skippped 2884 operations out of 3996
# 991983.245605
# done 1611, skippped 2385 operations out of 3996
# CPU times: user 1min 1s, sys: 40 ms, total: 1min 1s
# Wall time: 1min 2s
# <style>
#
# table
# {
#   border-collapse: collapse;
# }
# th
# {
#   color: #ffffff;
#   background-color: #000000;
# }
# td
# {
#   background-color: #cccccc;
# }
# table, th, td
# {
#   font-family:Arial, Helvetica, sans-serif;
#   border: 1px solid black;
#   text-align: center;
#   padding: 3px;
#   font-size:11pt;
# }
# g.mpld3-xaxis, g.mpld3-yaxis {
#     display: none;
# }
#
# </style>
#
# <div id="fig_el75821402099819557285417992034"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#     mpld3.register_plugin("htmltooltip", HtmlTooltipPlugin);
#     HtmlTooltipPlugin.prototype = Object.create(mpld3.Plugin.prototype);
#     HtmlTooltipPlugin.prototype.constructor = HtmlTooltipPlugin;
#     HtmlTooltipPlugin.prototype.requiredProps = ["id"];
#     HtmlTooltipPlugin.prototype.defaultProps = {labels:null, hoffset:0, voffset:10};
#     function HtmlTooltipPlugin(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     HtmlTooltipPlugin.prototype.draw = function(){
#        var obj = mpld3.get_element(this.props.id);
#        var labels = this.props.labels;
#        var tooltip = d3.select("body").append("div")
#                     .attr("class", "mpld3-tooltip")
#                     .style("position", "absolute")
#                     .style("z-index", "10")
#                     .style("visibility", "hidden");
#
#        obj.elements()
#            .on("mouseover", function(d, i){
#                               tooltip.html(labels[i])
#                                      .style("visibility", "visible");})
#            .on("mousemove", function(d, i){
#                     tooltip
#                       .style("top", d3.event.pageY + this.props.voffset + "px")
#                       .style("left",d3.event.pageX + this.props.hoffset + "px");
#                  }.bind(this))
#            .on("mouseout",  function(d, i){
#                            tooltip.style("visibility", "hidden");});
#     };
#
#        mpld3.draw_figure("fig_el75821402099819557285417992034", {"axes": [{"xlim": [-0.080000000000000002, 1.0800000000000001], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "PAP", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.64645909935844514, 0.87880902743838107], "rotation": -0.0, "id": "el7582140209921697936"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "VENTLUNG", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.72283035013240093, 0.35372115070512322], "rotation": -0.0, "id": "el7582140209921814928"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "SAO2", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.144972940974742, 0.76477754980139834], "rotation": -0.0, "id": "el7582140209921818320"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "SHUNT", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.26164534653843197, 0.69863650738130034], "rotation": -0.0, "id": "el7582140209921816016"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "HR", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.31637843444734143, 0.23631332613451847], "rotation": -0.0, "id": "el7582140209921817232"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "HREKG", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.49808761208676089, 0.094109811474450189], "rotation": -0.0, "id": "el7582140209921734800"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "CVP", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.17261014035421296, 0.58223740045596095], "rotation": -0.0, "id": "el7582140209921734864"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "KINKEDTUBE", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.38898283401534173, 0.53847028091746429], "rotation": -0.0, "id": "el7582140209921735888"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "BP", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.67512928756080159, 0.78565246250464582], "rotation": -0.0, "id": "el7582140209958647888"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "ERRCAUTER", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.38949424002959798, 0.39703790400438993], "rotation": -0.0, "id": "el7582140209958649744"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "PULMEMBOLUS", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.41706987333442991, 0.90080253883708916], "rotation": -0.0, "id": "el7582140209958645904"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "EXPCO2", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.53979590991976578, 0.14589377932659744], "rotation": -0.0, "id": "el7582140209921778064"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "MINVOLSET", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.20640485716599566, 0.0], "rotation": -0.0, "id": "el7582140209921779856"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "CATECHOL", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.75874647020945896, 0.21000850048678993], "rotation": -0.0, "id": "el7582140209921781200"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "ERRLOWOUTPUT", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [1.0, 0.56274658596747473], "rotation": -0.0, "id": "el ...

# %%
from graphmodels import GreedySearch
gs = GreedySearch(data, ScoreBIC)

# %%
# %%time
gs(max_iter=100).draw()
# Out:
# 60889.7189542
# 113552.484436
# 165754.643595
# 216923.178485
# 263877.542988
# 309303.341879
# 354272.587448
# 397594.118765
# 437586.675578
# 473717.466177
# 509338.160077
# 541232.30433
# 572872.257958
# 604099.371962
# 635112.509838
# 663898.342909
# 690590.871417
# 715887.480056
# 740977.777854
# 762906.08595
# 780430.01544
# 800252.235048
# 816914.334344
# 831715.380119
# 846493.139729
# 860845.597374
# 874965.064254
# 888165.24087
# 899851.302723
# 911018.202798
# 921623.268992
# 930811.436269
# 939068.357348
# 946249.241442
# 952453.975116
# 956778.001474
# 961068.16129
# 965090.668535
# 969111.855353
# 972483.997428
# 975534.780205
# 978532.215914
# 981501.785588
# 984323.464993
# 987042.320563
# 989335.608551
# 991513.682297
# 993529.184431
# 995298.384023
# 996720.577864
# 997945.711092
# 999011.301517
# 999138.677556
# 999238.809857
# 999330.91326
# 999454.790946
# 999512.455603
# 999563.679858
# CPU times: user 2min 38s, sys: 1.01 s, total: 2min 39s
# Wall time: 2min 39s
# <style>
#
# table
# {
#   border-collapse: collapse;
# }
# th
# {
#   color: #ffffff;
#   background-color: #000000;
# }
# td
# {
#   background-color: #cccccc;
# }
# table, th, td
# {
#   font-family:Arial, Helvetica, sans-serif;
#   border: 1px solid black;
#   text-align: center;
#   padding: 3px;
#   font-size:11pt;
# }
# g.mpld3-xaxis, g.mpld3-yaxis {
#     display: none;
# }
#
# </style>
#
# <div id="fig_el75821402106693204648320720188"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#     mpld3.register_plugin("htmltooltip", HtmlTooltipPlugin);
#     HtmlTooltipPlugin.prototype = Object.create(mpld3.Plugin.prototype);
#     HtmlTooltipPlugin.prototype.constructor = HtmlTooltipPlugin;
#     HtmlTooltipPlugin.prototype.requiredProps = ["id"];
#     HtmlTooltipPlugin.prototype.defaultProps = {labels:null, hoffset:0, voffset:10};
#     function HtmlTooltipPlugin(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     HtmlTooltipPlugin.prototype.draw = function(){
#        var obj = mpld3.get_element(this.props.id);
#        var labels = this.props.labels;
#        var tooltip = d3.select("body").append("div")
#                     .attr("class", "mpld3-tooltip")
#                     .style("position", "absolute")
#                     .style("z-index", "10")
#                     .style("visibility", "hidden");
#
#        obj.elements()
#            .on("mouseover", function(d, i){
#                               tooltip.html(labels[i])
#                                      .style("visibility", "visible");})
#            .on("mousemove", function(d, i){
#                     tooltip
#                       .style("top", d3.event.pageY + this.props.voffset + "px")
#                       .style("left",d3.event.pageX + this.props.hoffset + "px");
#                  }.bind(this))
#            .on("mouseout",  function(d, i){
#                            tooltip.style("visibility", "hidden");});
#     };
#
#        mpld3.draw_figure("fig_el75821402106693204648320720188", {"axes": [{"xlim": [-0.080000000000000002, 1.0658252805791972], "yscale": "linear", "axesbg": "#FFFFFF", "texts": [{"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "PAP", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.28531440608988207, 0.024221386921273496], "rotation": -0.0, "id": "el7582140209957966544"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "VENTLUNG", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.66504713226606293, 0.69526970873972971], "rotation": -0.0, "id": "el7582140209957968592"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "SAO2", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.4807003362961853, 0.29587357339792925], "rotation": -0.0, "id": "el7582140209920765200"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "SHUNT", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.57109552406942254, 0.53639446088960696], "rotation": -0.0, "id": "el7582140209920763920"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "HR", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.1829610620451981, 0.43588498381672647], "rotation": -0.0, "id": "el7582140209920762704"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "HREKG", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.32292270866643202, 0.26700186561173844], "rotation": -0.0, "id": "el7582140209920765328"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "CVP", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.24581347808436518, 0.53209083034409099], "rotation": -0.0, "id": "el7582140209926154768"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "KINKEDTUBE", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.69588787652983231, 1.0], "rotation": -0.0, "id": "el7582140209926155472"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "BP", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.14727817340214849, 0.61968565176316581], "rotation": -0.0, "id": "el7582140209926154128"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "ERRCAUTER", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.33052747912131564, 0.50097757328494874], "rotation": -0.0, "id": "el7582140209926155536"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "PULMEMBOLUS", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.6094956467687479, 0.026719870227156068], "rotation": -0.0, "id": "el7582140209922588048"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "EXPCO2", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.70233369670022672, 0.30315175137410738], "rotation": -0.0, "id": "el7582140209922588624"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "MINVOLSET", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.98527724978805953, 0.17638725778694508], "rotation": -0.0, "id": "el7582140209922584912"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "CATECHOL", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.24829847983742345, 0.098353929628460762], "rotation": -0.0, "id": "el7582140209955391248"}, {"v_baseline": "central", "h_anchor": "middle", "color": "#000000", "text": "ERRLOWOUTPUT", "coordinates": "data", "zorder": 3, "alpha": 1, "fontsize": 10.0, "position": [0.0, 0.47347755187180834], "rotation": -0.0, "id": "e ...

# %%
gs.fscore.mi_estimator.entropy_estimator.sg.nodes(data=True)
# Out:
# [(frozenset({'ARTCO2', 'CO'}), {'f': 1.5763543036515359}),
#  (frozenset({'DISCONNECT', 'LVEDVOLUME', 'PCWP'}), {'f': 1.3364205432453751}),
#  (frozenset({'HRSAT'}), {'f': 0.75335949022306459}),
#  (frozenset({'EXPCO2', 'PCWP'}), {'f': 1.3793444224493232}),
#  (frozenset({'LVFAILURE'}), {'f': 0.19907430985233129}),
#  (frozenset({'ARTCO2', 'HRSAT'}), {'f': 1.4238568477216866}),
#  (frozenset({'BP', 'PULMEMBOLUS'}), {'f': 1.1150631048365758}),
#  (frozenset({'CO'}), {'f': 0.89874580841592544}),
#  (frozenset({'HR', 'MINVOL', 'VENTALV'}), {'f': 1.7113281283301314}),
#  (frozenset({'HISTORY', 'VENTALV', 'VENTLUNG'}), {'f': 1.3347501946108049}),
#  (frozenset({'PRESS', 'PVSAT', 'VENTALV'}), {'f': 2.0824744996641069}),
#  (frozenset({'DISCONNECT', 'HREKG', 'HRSAT'}), {'f': 1.3239594044904286}),
#  (frozenset({'MINVOLSET', 'VENTALV'}), {'f': 1.2152058604863021}),
#  (frozenset({'MINVOL', 'PAP', 'VENTALV'}), {'f': 1.6200649656904429}),
#  (frozenset({'ANAPHYLAXIS', 'INSUFFANESTH'}), {'f': 0.38276954472320385}),
#  (frozenset({'ARTCO2', 'LVEDVOLUME', 'PCWP'}), {'f': 1.7031574582924489}),
#  (frozenset({'HR', 'TPR'}), {'f': 1.5803917464894077}),
#  (frozenset({'PRESS', 'PVSAT', 'SAO2'}), {'f': 1.8276246887308136}),
#  (frozenset({'CATECHOL', 'ERRLOWOUTPUT'}), {'f': 0.52971905501849359}),
#  (frozenset({'HREKG', 'HRSAT', 'STROKEVOLUME'}), {'f': 1.6361639505327183}),
#  (frozenset({'HISTORY', 'VENTALV'}), {'f': 1.1068971485376791}),
#  (frozenset({'CO', 'VENTLUNG'}), {'f': 1.5923286383314026}),
#  (frozenset({'KINKEDTUBE', 'PRESS'}), {'f': 1.268794189545464}),
#  (frozenset({'ARTCO2', 'MINVOL', 'VENTALV'}), {'f': 1.3722701884063473}),
#  (frozenset({'ANAPHYLAXIS', 'SHUNT'}), {'f': 0.38666732573930213}),
#  (frozenset({'KINKEDTUBE', 'LVEDVOLUME', 'PCWP'}), {'f': 1.1784746089425431}),
#  (frozenset({'CO', 'VENTALV', 'VENTLUNG'}), {'f': 2.0089061654449392}),
#  (frozenset({'MINVOL', 'PVSAT', 'SAO2'}), {'f': 1.226682523703285}),
#  (frozenset({'HYPOVOLEMIA', 'VENTMACH'}), {'f': 1.1233232267177526}),
#  (frozenset({'LVEDVOLUME', 'VENTMACH'}), {'f': 1.4140755864677874}),
#  (frozenset({'HR', 'HRBP', 'HYPOVOLEMIA'}), {'f': 1.310971127830507}),
#  (frozenset({'HR', 'HRBP', 'VENTALV'}), {'f': 1.6821969940654236}),
#  (frozenset({'CVP', 'LVEDVOLUME', 'PVSAT'}), {'f': 1.6765410181780442}),
#  (frozenset({'HRBP', 'VENTALV'}), {'f': 1.5586424776875092}),
#  (frozenset({'CVP', 'PVSAT', 'SAO2'}), {'f': 1.4949153945416986}),
#  (frozenset({'ARTCO2', 'PCWP'}), {'f': 1.529466393685563}),
#  (frozenset({'INSUFFANESTH', 'LVEDVOLUME'}), {'f': 1.1191461990158249}),
#  (frozenset({'HR', 'HRSAT', 'INTUBATION'}), {'f': 1.2525376906670509}),
#  (frozenset({'HRSAT', 'LVEDVOLUME'}), {'f': 1.5442119357613768}),
#  (frozenset({'CVP', 'LVEDVOLUME', 'SHUNT'}), {'f': 1.4385743774495756}),
#  (frozenset({'HR', 'MINVOL'}), {'f': 1.3520927616857645}),
#  (frozenset({'PVSAT', 'SHUNT'}), {'f': 0.89996934142128227}),
#  (frozenset({'CATECHOL', 'SAO2'}), {'f': 0.8824382799567847}),
#  (frozenset({'INTUBATION', 'LVFAILURE'}), {'f': 0.53231847277901656}),
#  (frozenset({'CATECHOL', 'CVP', 'LVEDVOLUME'}), {'f': 1.4350227769738277}),
#  (frozenset({'ARTCO2', 'TPR', 'VENTALV'}), {'f': 2.1498158328462122}),
#  (frozenset({'DISCONNECT', 'PCWP'}), {'f': 1.1626975997627638}),
#  (frozenset({'PAP', 'SAO2'}), {'f': 1.0074419387709068}),
#  (frozenset({'PULMEMBOLUS', 'PVSAT', 'SAO2'}), {'f': 0.77945497264715147}),
#  (frozenset({'BP', 'SAO2'}), {'f': 1.6521602369833313}),
#  (frozenset({'ARTCO2', 'VENTMACH'}), {'f': 1.2151870089736978}),
#  (frozenset({'HRBP'}), {'f': 0.68446208762072647}),
#  (frozenset({'ERRCAUTER', 'PVSAT'}), {'f': 0.89042018676617662}),
#  (frozenset({'ANAPHYLAXIS', 'HISTORY'}), {'f': 0.26582545249456629}),
#  (frozenset({'ARTCO2', 'PAP'}), {'f': 1.1045661478244475}),
#  (frozenset({'FIO2', 'LVFAILURE'}), {'f': 0.39979196118332194}),
#  (frozenset({'CO', 'PVSAT', 'VENTALV'}), {'f': 1.8938560164456077}),
#  (frozenset({'HREKG', 'HRSAT', 'TPR'}), {'f': 2.0580217415498487}),
#  (frozenset({'HISTORY', 'KINKEDTUBE'}), {'f': 0.37831977291957841}),
#  (frozenset({'PRESS', 'STROKEVOLUME'}), {'f': 1.7546073645448388}),
#  (frozenset({'ARTCO2', 'FIO2'}), {'f': 0.8924701880140703}),
#  (frozenset({'VENTMACH'}), {'f': 0.62321429302014109}),
#  (frozenset({'LVEDVOLUME', 'STROKEVOLUME'}), {'f': 1.3197754477849541}),
#  (frozenset({'DISCONNECT', 'VENTMACH'}), {'f': 0.94818095768473254}),
#  (frozenset({'VENTTUBE'}), {'f': 0.77577700912657244}),
#  (frozenset({'HREKG', 'HRSAT', 'MINVOL'}), {'f': 1.8270734581809676}),
#  (frozenset({'EXPCO2', 'HRBP'}), {'f': 1.2241564928334667}),
#  (frozenset({'SAO2', 'VENTALV', 'VENTLUNG'}), {'f': 1.3442899854168175}),
#  (frozenset({'ARTCO2', 'LVFAILURE', 'VENTALV'}), {'f': 1.2595641615819673}),
#  (frozenset({'CVP', 'HREKG', 'LVEDVOLUME'}), {'f': 1.8627370618772305}),
#  (frozenset({'CVP', 'DISCONNECT'}), {'f': 1.0923302478719255}),
#  (frozenset({'HISTORY', 'INSUFFANESTH'}), {'f': 0.539553544116674}),
#  (frozenset({'INTUBATION', 'VENTALV'}), {'f': 1.0816033434018184}),
#  (frozenset({'DISCONNECT', 'TPR'}), {'f': 1.4143704351539732}),
#  (frozenset({'BP', 'CVP', 'LVEDVOLUME'}), {'f': 2.1520348216751701}),
#  (frozenset({'ERRCAUTER'}), {'f': 0.32031088236284228}),
#  (frozenset({'DISCONNECT', 'FIO2'}), {'f': 0.52569072813537854}),
#  (frozenset({'ERRLOWOUTPUT', 'PVSAT'}), {'f': 0.77126451307455957}),
#  (frozenset({'CO', 'HYPOVOLEMIA'}), {'f': 1.3402187052131644}),
#  (frozenset({'ARTCO2', 'HREKG'}), {'f': 1.426775321169842}),
#  (frozenset({'VENTALV', 'VENTLUNG', 'VENTMACH'}), {'f': 1.6048601173177826}),
#  (frozenset({'PCWP'}), {'f': 0.83772452154089316}),
#  (frozenset({'CVP', 'VENTALV', 'VENTLUNG'}), {'f': 1.8906956567798212}),
#  (frozenset({'BP', 'VENTALV', 'VENTLUNG'}), {'f': 2.1803026097087645}),
#  (frozenset({'HR', 'HRBP', 'HREKG'}), {'f': 1.2064311968800747}),
#  (frozenset({'MINVOL', 'VENTLUNG'}), {'f': 1.1339384359348923}),
#  (frozenset({'BP', 'HREKG'}), {'f': 1.795461107392109}),
#  (frozenset({'PAP', 'SHUNT'}), {'f': 0.74195388454345823}),
#  (frozenset({'HRBP', 'VENTALV', 'VENTLUNG'}), {'f': 1.7864297289819713}),
#  (frozenset({'ERRCAUTER', 'ERRLOWOUTPUT'}), {'f': 0.52146429496405944}),
#  (frozenset({'BP', 'SHUNT'}), {'f': 1.3916775570714484}),
#  (frozenset({'LVEDVOLUME', 'PCWP', 'VENTALV'}), {'f': 1.9069666979299751}),
#  (frozenset({'HYPOVOLEMIA', 'VENTLUNG'}), {'f': 1.203140279397509}),
#  (frozenset({'CVP', 'LVEDVOLUME', 'TPR'}), {'f': 2.1958671637802141}),
#  (frozenset({'PULMEMBOLUS', 'PVSAT', 'VENTALV'}), {'f': 1.0640335824162834}),
#  (frozenset({'ARTCO2', 'CATECHOL', 'VENTALV'}), {'f': 1.3327898778679004}),
#  (frozenset({'DISCONNECT', 'HREKG'}), {'f': 1.0790370226068711}),
#  (frozenset({'ANAPHYLAXIS', 'FIO2'}), {'f': 0.25524356077440763}),
#  (frozenset({'ANAPHYLAXIS', 'CATECHOL'}), {'f': 0.38243187533222844}),
#  (frozenset({'PULMEMBOLUS', 'VENTALV'}), {'f': 0.95114324894936819}),
#  (frozenset({'LVEDVOLUME', 'MINVOL', 'PCWP'}), {'f': 1.854307037729843}),
#  (frozenset({'EXPCO2', 'VENTMACH'}), {'f': 1.1543425944830377}),
#  (frozenset({'CVP', 'HREKG', 'HRSAT'}), {'f': 1.7686644235267193}),
#  (frozenset({'VENTALV', 'VENTTUBE'}), {'f': 1.4092123669240195}),
#  (frozenset({'LVFAILURE', 'SAO2'}), {'f': 0.79386274138681645}),
#  (frozenset({'EXPCO2', 'VENTALV'}), {'f': 1.318856812203721}),
#  (frozenset({'MINVOLSET', 'PVSAT', 'SAO2'}), {'f': 1.0617945227257264}),
#  (frozenset({'HR', 'HRBP', 'PRESS'}), {'f': 1.9297381389347499}),
#  (frozenset({'MINVOL', 'VENTALV'}), {'f': 1.2074215757364655}),
#  (frozenset({'CO', 'HRSAT'}), {'f': 1.464508989331571}),
#  (frozenset({'CVP', 'PVSAT'}), {'f': 1.3374780260223995}),
#  (frozenset({'ARTCO2', 'LVFAILURE'}), {'f': 0.89082383705645829}),
#  (frozenset({'CO', 'LVFAILURE'}), {'f': 1.0417652239509272}),
#  (frozenset({'ANAPHYLAXIS', 'ARTCO2', 'VENTALV'}), {'f': 1.1150146664692859}),
#  (frozenset({'FIO2', 'VENTALV', 'VENTLUNG'}), {'f': 1.3241360236580346}),
#  (frozenset({'EXPCO2', 'SHUNT'}), {'f': 0.85173904965991687}),
#  (frozenset({'ARTCO2', 'MINVOLSET', 'VENTALV'}), {'f': 1.3800793494632206}),
#  (frozenset({'CVP', 'INTUBATION', 'LVEDVOLUME'}), {'f': 1.4396643153570916}),
#  (frozenset({'CVP', 'LVEDVOLUME', 'PCWP'}), {'f': 1.3269942988859267}),
#  (frozenset({'ARTCO2', 'BP'}), {'f': 1.7485072101597854}),
#  (frozenset({'ERRLOWOUTPUT', 'INSUFFANESTH'}), {'f': 0.52941304194473837}),
#  (frozenset({'ANAPHYLAXIS', 'STROKEVOLUME'}), {'f': 0.68934154733639352}),
#  (frozenset({'LVEDVOLUME', 'LVFAILURE'}), {'f': 0.86048576814288924}),
#  (frozenset({'HYPOVOLEMIA', 'SAO2'}), {'f': 1.094901150538242}),
#  (frozenset({'EXPCO2', 'HREKG', 'HRSAT'}), {'f': 1.5411638047503828}),
#  (frozenset({'CVP', 'HR', 'HRBP'}), {'f': 1.5782910740375102}),
#  (frozenset({'ERRCAUTER', 'LVFAILURE'}), {'f': 0.5193392391886511}),
#  (frozenset({'VENTLUNG'}), {'f': 0.7030419608731715}),
#  (frozenset({'HISTORY', 'PRESS'}), {'f': 1.3310977698387738}),
#  (frozenset({'HISTORY', 'PCWP'}), {'f': 0.97543615288945562}),
#  (frozenset({'PAP', 'VENTALV'}), {'f': 1.3084106996791052}),
#  (frozenset({'MINVOL', 'MINVOLSET', 'VENTALV'}), {'f': 1.519579862950307}),
#  (frozenset({'MINVOL', 'PCWP'}), {'f': 1.6806152473893234}),
#  (frozenset({'FIO2', 'PVSAT', 'VENTALV'}), {'f': 1.1793369496555395}),
#  (frozenset({'BP', 'VENTALV'}), {'f': 1.9525052541017116}),
#  (frozenset({'CVP', 'MINVOL'}), {'f': 1.6102804913463162}),
#  (frozenset({'HR', 'HRSAT', 'PRESS'}), {'f': 2.0382807455106957}),
#  (frozenset({'BP', 'HYPOVOLEMIA'}), {'f': 1.5472880720949838}),
#  (frozenset({'MINVOLSET', 'PVSAT', 'VENTALV'}), {'f': 1.3280615364187534}),
#  (frozenset({'LVFAILURE', 'MINVOL'}), {'f': 1.0419772063319983}),
#  (frozenset({'PAP', 'PVSAT', 'VENTALV'}), {'f': 1.4212725808914668}),
#  (frozenset({'HR', 'HRBP', 'KINKEDTUBE'}), {'f': 0.97779355622768116}),
#  (frozenset({'ARTCO2', 'VENTALV'}), {'f': 1.0605599999211093}),
#  (frozenset({'KINKEDTUBE', 'VENTTUBE'}), {'f': 0.94278986758225969}),
#  (frozenset({'CVP', 'PRESS'}), {'f': 1.8871525787604955}),
#  (frozenset({'PCWP', 'TPR'}), {'f': 1.9271349118499097}),
#  (frozenset({'PRESS', 'TPR'}), {'f': 2.20915565213522}),
#  (frozenset({'HR', 'PVSAT', 'SAO2'}), {'f': 1.2345835711422848}),
#  (frozenset({'ANAPHYLAXIS', 'EXPCO2'}), {'f': 0.59617350900196653}),
#  (frozenset({'HR', 'HRSAT', 'MINVOL'}), {'f': 1.7431724773048296}),
#  (frozenset({'ERRCAUTER', 'INSUFFANESTH'}), {'f': 0.64856322653074139}),
#  (frozenset({'HISTORY', 'HR', 'HRBP'}), {'f': 1.0222972830312698}),
#  (frozenset({'HISTORY', 'INTUBATION'}), {'f': 0.54454531825198138}),
#  (frozenset({'CO', 'CVP', 'LVEDVOLUME'}), {'f': 1.9333670169996}),
#  (frozenset({'LVFAILURE', 'MINVOLSET'}), {'f': 0.59468527939281735}),
#  (frozenset({'HR', 'STROKEVOLUME'}), {'f': 1.163175896760098}),
#  (frozenset({'CO', 'MINVOLSET'}), {'f': 1.2921726931069335}),
#  (frozenset({'CVP', 'HISTORY'}), {'f': 0.90596284389170079}),
#  (frozenset({'HR', 'VENTALV', 'VENTLUNG'}), {'f': 1.6274512303613373}),
#  (frozenset({'HR', 'HRSAT', 'MINVOLSET'}), {'f': 1.3112839618312351}),
#  (frozenset({'VENTLUNG', 'VENTTUBE'}), {'f': 1.2379754366289335}),
#  (frozenset({'CVP', 'HRSAT'}), {'f': 1.5206712570423728}),
#  (frozenset({'MINVOLSET', 'SAO2'}), {'f': 0.93729146503907323}),
#  (frozenset({'HREKG', 'PVSAT', 'VENTALV'}), {'f': 1.7446727685034042}),
#  (frozenset({'BP'}), {'f': 1.0595516841719672}),
#  (frozenset({'HYPOVOLEMIA', 'VENTALV', 'VENTLUNG'}),
#   {'f': 1.6235280374105117}),
#  (frozenset({'HR', 'MINVOLSET'}), {'f': 0.92017132646195476}),
#  (frozenset({'PULMEMBOLUS', 'VENTLUNG'}), {'f': 0.75857430072113252}),
#  (frozenset({'ARTCO2', 'CATECHOL'}), {'f': 0.9643691348483604}),
#  (frozenset({'MINVOL', 'VENTALV', 'VENTTUBE'}), {'f': 1.6892939556755668}),
#  (frozenset({'PVSAT', 'SAO2', 'VENTLUNG'}), {'f': 1.1088332182135447}),
#  (frozenset({'ARTCO2', 'PULMEMBOLUS'}), {'f': 0.74729221919608368}),
#  (frozenset({'CVP', 'LVEDVOLUME', 'STROKEVOLUME'}), {'f': 1.6352919511780954}),
#  (frozenset({'ERRCAUTER', 'EXPCO2'}), {'f': 0.86195646962816463}),
#  (frozenset({'EXPCO2', 'PAP'}), {'f': 0.95445895497989086}),
#  (frozenset({'HISTORY', 'HREKG'}), {'f': 0.9675746271459138}),
#  (frozenset({'INTUBATION', 'LVEDVOLUME'}), {'f': 1.124135161811904}),
#  (frozenset({'ARTCO2', 'INSUFFANESTH', 'VENTALV'}), {'f': 1.3887222005748507}),
#  (frozenset({'BP', 'VENTLUNG'}), {'f': 1.7608018393488842}),
#  (frozenset({'PAP', 'PULMEMBOLUS'}), {'f': 0.45022836952211215}),
#  (frozenset({'ERRLOWOUTPUT', 'PVSAT', 'VENTALV'}), {'f': 1.2096664681674736}),
#  (frozenset({'EXPCO2', 'KINKEDTUBE'}), {'f': 0.70768878593629325}),
#  (frozenset({'HREKG', 'MINVOLSET'}), {'f': 1.1487916356869456}),
#  (frozenset({'HYPOVOLEMIA'}), {'f': 0.5001111647068035}),
#  (frozenset({'CATECHOL', 'MINVOL'}), {'f': 1.1309523201091816}),
#  (frozenset({'CATECHOL', 'PVSAT', 'SAO2'}), {'f': 1.0121418906589579}),
#  (frozenset({'HRBP', 'SHUNT'}), {'f': 1.0165972651179851}),
#  (frozenset({'HR', 'HRBP', 'INSUFFANESTH'}), {'f': 1.139197432376811}),
#  (frozenset({'DISCONNECT', 'KINKEDTUBE'}), {'f': 0.49199277634198657}),
#  (frozenset({'CVP', 'LVEDVOLUME', 'VENTLUNG'}), {'f': 1.8094240377286428}),
#  (frozenset({'DISCONNECT', 'PVSAT', 'SAO2'}), {'f': 1.0173485965646845}),
#  (frozenset({'MINVOLSET', 'VENTMACH'}), {'f': 0.70565318926637366}),
#  (frozenset({'KINKEDTUBE', 'PVSAT'}), {'f': 0.73141853043069061}),
#  (frozenset({'LVEDVOLUME', 'PCWP', 'STROKEVOLUME'}),
#   {'f': 1.5403422242219078}),
#  (frozenset({'HRSAT', 'SAO2'}), {'f': 1.3318178395119513}),
#  (frozenset({'CATECHOL', 'MINVOLSET'}), {'f': 0.71639794950238445}),
#  (frozenset({'BP', 'KINKEDTUBE'}), {'f': 1.2265517797780494}),
#  (frozenset({'ANAPHYLAXIS', 'CVP'}), {'f': 0.82188485335781913}),
#  (frozenset({'FIO2', 'MINVOLSET'}), {'f': 0.59634387285262602}),
#  (frozenset({'BP', 'PVSAT', 'SAO2'}), {'f': 1.7847679105973395}),
#  (frozenset({'SHUNT', 'VENTLUNG'}), {'f': 1.0304911064750033}),
#  (frozenset({'PULMEMBOLUS', 'VENTTUBE'}), {'f': 0.83128104088351074}),
#  (frozenset({'HR', 'PRESS'}), {'f': 1.6471785596163064}),
#  (frozenset({'CVP', 'INTUBATION'}), {'f': 1.1005757917559633}),
#  (frozenset({'HREKG', 'PULMEMBOLUS'}), {'f': 0.81186289240905563}),
#  (frozenset({'CVP', 'PAP'}), {'f': 1.1801624127723436}),
#  (frozenset({'CVP', 'KINKEDTUBE'}), {'f': 0.93438225434295374}),
#  (frozenset({'HR', 'HYPOVOLEMIA'}), {'f': 1.0284882679956648}),
#  (frozenset({'INSUFFANESTH', 'PVSAT'}), {'f': 0.898337513834775}),
#  (frozenset({'ERRCAUTER', 'MINVOL', 'VENTALV'}), {'f': 1.5276441070421725}),
#  (frozenset({'MINVOL', 'STROKEVOLUME'}), {'f': 1.4777215240168875}),
#  (frozenset({'HRBP', 'PAP'}), {'f': 1.097277024476452}),
#  (frozenset({'PVSAT', 'VENTLUNG'}), {'f': 0.95156845837339787}),
#  (frozenset({'LVEDVOLUME', 'PCWP', 'PULMEMBOLUS'}), {'f': 1.0670141711167458}),
#  (frozenset({'HR', 'HRBP', 'MINVOLSET'}), {'f': 1.2027602644067463}),
#  (frozenset({'HYPOVOLEMIA', 'SHUNT'}), {'f': 0.83225240522684241}),
#  (frozenset({'ERRCAUTER', 'FIO2'}), {'f': 0.52101983510537031}),
#  (frozenset({'HR', 'HRSAT', 'PVSAT'}), {'f': 1.4685301462511453}),
#  (frozenset({'ANAPHYLAXIS', 'HREKG', 'HRSAT'}), {'f': 1.0557989295445604}),
#  (frozenset({'LVFAILURE', 'PVSAT'}), {'f': 0.76918346299852447}),
#  (frozenset({'BP', 'MINVOL', 'VENTALV'}), {'f': 2.2642336210474738}),
#  (frozenset({'HR', 'LVFAILURE'}), {'f': 0.72745647333300312}),
#  (frozenset({'EXPCO2', 'INTUBATION'}), {'f': 0.81400403050178671}),
#  (frozenset({'HISTORY', 'HYPOVOLEMIA'}), {'f': 0.71140707486049448}),
#  (frozenset({'PVSAT', 'TPR'}), {'f': 1.6595039853130311}),
#  (frozenset({'HRSAT', 'VENTTUBE'}), {'f': 1.5188976201905047}),
#  (frozenset({'CO', 'PULMEMBOLUS'}), {'f': 0.95426877329575577}),
#  (frozenset({'HRBP', 'VENTTUBE'}), {'f': 1.4496298034021402}),
#  (frozenset({'BP', 'PCWP'}), {'f': 1.8867601773043841}),
#  (frozenset({'CVP', 'VENTMACH'}), {'f': 1.3905611055780636}),
#  (frozenset({'ERRCAUTER', 'PVSAT', 'SAO2'}), {'f': 1.0478869137438442}),
#  (frozenset({'ARTCO2', 'MINVOLSET'}), {'f': 1.0284634186983193}),
#  (frozenset({'VENTALV', 'VENTMACH'}), {'f': 1.3932763490831634}),
#  (frozenset({'ERRCAUTER', 'KINKEDTUBE'}), {'f': 0.48733230048275189}),
#  (frozenset({'MINVOL', 'PAP'}), {'f': 1.2557136899180323}),
#  (frozenset({'FIO2', 'PRESS'}), {'f': 1.3205018978154111}),
#  (frozenset({'ERRCAUTER', 'SAO2'}), {'f': 0.91509946864361502}),
#  (frozenset({'HRSAT', 'VENTALV'}), {'f': 1.6288588705233511}),
#  (frozenset({'CVP', 'VENTALV'}), {'f': 1.6629465425390373}),
#  (frozenset({'CO', 'KINKEDTUBE'}), {'f': 1.065676217580368}),
#  (frozenset({'PCWP', 'PULMEMBOLUS'}), {'f': 0.89326125294901726}),
#  (frozenset({'CVP', 'FIO2', 'LVEDVOLUME'}), {'f': 1.3071902954289547}),
#  (frozenset({'ERRCAUTER', 'HREKG', 'HRSAT'}), {'f': 1.0660592836921547}),
#  (frozenset({'MINVOL', 'STROKEVOLUME', 'VENTALV'}), {'f': 1.8420901006465886}),
#  (frozenset({'HISTORY', 'HRBP'}), {'f': 0.89575961978793095}),
#  (frozenset({'DISCONNECT', 'PRESS'}), {'f': 1.402653543644911}),
#  (frozenset({'PCWP', 'PVSAT'}), {'f': 1.4078187139360161}),
#  (frozenset({'HR', 'VENTALV'}), {'f': 1.3996487513458817}),
#  (frozenset({'PRESS', 'PULMEMBOLUS'}), {'f': 1.17531099069373}),
#  (frozenset({'ERRLOWOUTPUT', 'PVSAT', 'SAO2'}), {'f': 0.92870220423497352}),
#  (frozenset({'BP', 'TPR'}), {'f': 1.8327365712795662}),
#  (frozenset({'PRESS', 'VENTALV'}), {'f': 1.9696228420641839}),
#  (frozenset({'EXPCO2', 'HRSAT'}), {'f': 1.2933082328411474}),
#  (frozenset({'EXPCO2', 'VENTALV', 'VENTLUNG'}), {'f': 1.3809055780913198}),
#  (frozenset({'HREKG', 'PCWP'}), {'f': 1.5940319596242021}),
#  (frozenset({'TPR', 'VENTMACH'}), {'f': 1.7125992538349653}),
#  (frozenset({'ERRLOWOUTPUT', 'KINKEDTUBE'}), {'f': 0.36817652153379565}),
#  (frozenset({'CO', 'EXPCO2'}), {'f': 1.4392397469592619}),
#  (frozenset({'CO', 'PAP'}), {'f': 1.3115504344823976}),
#  (frozenset({'BP', 'HR', 'HRSAT'}), {'f': 1.950786313902765}),
#  (frozenset({'LVFAILURE', 'VENTMACH'}), {'f': 0.82226730870064679}),
#  (frozenset({'BP', 'CO'}), {'f': 1.8332254539445554}),
#  (frozenset({'ARTCO2', 'CVP'}), {'f': 1.4591175006227539}),
#  (frozenset({'ANAPHYLAXIS', 'HR', 'HRBP'}), {'f': 0.86537780237756923}),
#  (frozenset({'HR', 'VENTTUBE'}), {'f': 1.2921177516159814}),
#  (frozenset({'ANAPHYLAXIS', 'CVP', 'LVEDVOLUME'}), {'f': 1.1610058429890726}),
#  (frozenset({'CVP', 'LVEDVOLUME', 'MINVOLSET'}), {'f': 1.5020191914366872}),
#  (frozenset({'PCWP', 'STROKEVOLUME'}), {'f': 1.3876786650445834}),
#  (frozenset({'FIO2', 'MINVOL', 'VENTALV'}), {'f': 1.4080675384850472}),
#  (frozenset({'HRSAT', 'MINVOL', 'VENTALV'}), {'f': 1.9405280890847014}),
#  (frozenset({'INSUFFANESTH', 'MINVOLSET'}), {'f': 0.72387757119560536}),
#  (frozenset({'DISCONNECT', 'HR', 'HRSAT'}), {'f': 1.2418181965739428}),
#  (frozenset({'HRBP', 'PULMEMBOLUS'}), {'f': 0.73999440501958069}),
#  (frozenset({'HREKG', 'LVEDVOLUME', 'PCWP'}), {'f': 1.7676870359807382}),
#  (frozenset({'HREKG', 'SAO2'}), {'f': 1.3349945620256598}),
#  (frozenset({'KINKEDTUBE', 'STROKEVOLUME'}), {'f': 0.80183214761677957}),
#  (frozenset({'INSUFFANESTH', 'LVFAILURE'}), {'f': 0.52732025209468247}),
#  (frozenset({'SAO2', 'SHUNT'}), {'f': 0.91061355972250202}),
#  (frozenset({'CVP', 'SHUNT'}), {'f': 1.0994936963966211}),
#  (frozenset({'ERRLOWOUTPUT', 'HR'}), {'f': 0.72953768990832568}),
#  (frozenset({'HREKG', 'TPR'}), {'f': 1.8158806351396115}),
#  (frozenset({'KINKEDTUBE', 'VENTLUNG'}), {'f': 0.86179311677270942}),
#  (frozenset({'CO', 'LVEDVOLUME'}), {'f': 1.6178200240351539}),
#  (frozenset({'ARTCO2', 'SHUNT'}), {'f': 1.0082024597761203}),
#  (frozenset({'HRSAT', 'INSUFFANESTH'}), {'f': 1.08158497068943}),
#  (frozenset({'HREKG', 'PAP'}), {'f': 1.1691481472354117}),
#  (frozenset({'HR', 'HREKG', 'HRSAT'}), {'f': 1.1051385216237977}),
#  (frozenset({'HR', 'INTUBATION'}), {'f': 0.8614399068470846}),
#  (frozenset({'EXPCO2', 'LVFAILURE'}), {'f': 0.7407222776291702}),
#  (frozenset({'MINVOL', 'PVSAT'}), {'f': 1.0707805247034856}),
#  (frozenset({'HREKG', 'PVSAT'}), {'f': 1.3092047543648087}),
#  (frozenset({'ARTCO2', 'CVP', 'LVEDVOLUME'}), {'f': 1.7981984661264396}),
#  (frozenset({'BP', 'INTUBATION'}), {'f': 1.3927814706040988}),
#  (frozenset({'INSUFFANESTH', 'LVEDVOLUME', 'PCWP'}), {'f': 1.339721663071715}),
#  (frozenset({'CATECHOL', 'PVSAT', 'VENTALV'}), {'f': 1.2844437396919353}),
#  (frozenset({'CATECHOL', 'KINKEDTUBE'}), {'f': 0.49508365288445216}),
#  (frozenset({'DISCONNECT', 'LVEDVOLUME'}), {'f': 1.1158643521571179}),
#  (frozenset({'ANAPHYLAXIS', 'BP'}), {'f': 1.1079182099869909}),
#  (frozenset({'VENTALV', 'VENTLUNG', 'VENTTUBE'}), {'f': 1.5953704300454759}),
#  (frozenset({'PRESS', 'SHUNT'}), {'f': 1.4482878747207089}),
#  (frozenset({'ERRCAUTER', 'HR'}), {'f': 0.84868776489182296}),
#  (frozenset({'HR', 'HRSAT', 'VENTTUBE'}), {'f': 1.6831925834522741}),
#  (frozenset({'PULMEMBOLUS', 'PVSAT'}), {'f': 0.62564871159800772}),
#  (frozenset({'INTUBATION', 'SHUNT'}), {'f': 0.55552711731502502}),
#  (frozenset({'INSUFFANESTH', 'PVSAT', 'VENTALV'}), {'f': 1.3367189941362885}),
#  (frozenset({'LVEDVOLUME', 'PCWP', 'PVSAT'}), {'f': 1.5815345177718996}),
#  (frozenset({'ARTCO2', 'PULMEMBOLUS', 'VENTALV'}), {'f': 1.1160337573246748}),
#  (frozenset({'CO', 'TPR'}), {'f': 1.9691187174673099}),
#  (frozenset({'BP', 'VENTMACH'}), {'f': 1.6819437553837799}),
#  (frozenset({'DISCONNECT', 'ERRCAUTER'}), {'f': 0.64526234080862133}),
#  (frozenset({'EXPCO2', 'HR'}), {'f': 1.0678711535099039}),
#  (frozenset({'INTUBATION', 'KINKEDTUBE'}), {'f': 0.50025269416045204}),
#  (frozenset({'INSUFFANESTH', 'STROKEVOLUME'}), {'f': 0.96307593319047824}),
#  (frozenset({'STROKEVOLUME', 'VENTALV'}), {'f': 1.5304247155069872}),
#  (frozenset({'BP', 'PAP'}), {'f': 1.4723573159315362}),
#  (frozenset({'INTUBATION', 'PVSAT', 'SAO2'}), {'f': 1.0465115011421808}),
#  (frozenset({'CATECHOL', 'VENTLUNG'}), {'f': 0.99536673895164074}),
#  (frozenset({'HR', 'HRBP', 'INTUBATION'}), {'f': 1.14401105239197}),
#  (frozenset({'CATECHOL', 'PULMEMBOLUS'}), {'f': 0.38409169416208339}),
#  (frozenset({'LVEDVOLUME', 'PCWP', 'TPR'}), {'f': 2.1008324285400226}),
#  (frozenset({'LVFAILURE', 'MINVOL', 'VENTALV'}), {'f': 1.4064094948948382}),
#  (frozenset({'HISTORY', 'MINVOL'}), {'f': 1.0542155102889892}),
#  (frozenset({'BP', 'VENTTUBE'}), {'f': 1.8339707562547336}),
#  (frozenset({'MINVOLSET', 'PRESS'}), {'f': 1.474215913218446}),
#  (frozenset({'LVEDVOLUME', 'PVSAT', 'SAO2'}), {'f': 1.5184194410866778}),
#  (frozenset({'MINVOLSET', 'PCWP'}), {'f': 1.2333378681044107}),
#  (frozenset({'PAP', 'VENTTUBE'}), {'f': 1.1885701161696729}),
#  (frozenset({'ERRCAUTER', 'HR', 'HRBP'}), {'f': 1.1312666598820391}),
#  (frozenset({'PVSAT', 'SAO2', 'VENTALV'}), {'f': 1.1635008142611283}),
#  (frozenset({'CVP', 'LVEDVOLUME', 'MINVOL'}), {'f': 1.9492882548232002}),
#  (frozenset({'CVP', 'HR', 'HRSAT'}), {'f': 1.686814332787504}),
#  (frozenset({'ERRCAUTER', 'HR', 'HRSAT'}), {'f': 0.98987261152982731}),
#  (frozenset({'ARTCO2', 'VENTTUBE'}), {'f': 1.2674777575458001}),
#  (frozenset({'PULMEMBOLUS'}), {'f': 0.055541520158535244}),
#  (frozenset({'INTUBATION', 'VENTALV', 'VENTLUNG'}), {'f': 1.1920453809701905}),
#  (frozenset({'HRBP', 'MINVOL'}), {'f': 1.510383686374418}),
#  (frozenset({'ARTCO2', 'HR', 'VENTALV'}), {'f': 1.5626159356402707}),
#  (frozenset({'EXPCO2', 'INSUFFANESTH'}), {'f': 0.8699004713034606}),
#  (frozenset({'HRBP', 'HREKG', 'HRSAT'}), {'f': 1.3409208413505793}),
#  (frozenset({'ARTCO2', 'STROKEVOLUME', 'VENTALV'}), {'f': 1.6952515216613482}),
#  (frozenset({'MINVOL', 'TPR'}), {'f': 1.9323333664501461}),
#  (frozenset({'FIO2', 'LVEDVOLUME'}), {'f': 0.99159519675588526}),
#  (frozenset({'CATECHOL', 'STROKEVOLUME'}), {'f': 0.96336741232570045}),
#  (frozenset({'HRBP', 'PRESS'}), {'f': 1.8034314082559473}),
#  (frozenset({'HRBP', 'PCWP'}), {'f': 1.5221810752959641}),
#  (frozenset({'FIO2', 'VENTALV'}), {'f': 1.0963172169757494}),
#  (frozenset({'MINVOL', 'SHUNT'}), {'f': 1.1408587947242579}),
#  (frozenset({'CVP', 'PCWP'}), {'f': 1.243638877503082}),
#  (frozenset({'HRSAT', 'PCWP'}), {'f': 1.5910664579440983}),
#  (frozenset({'HISTORY', 'PAP'}), {'f': 0.62412264696344433}),
#  (frozenset({'HR', 'HRBP', 'VENTMACH'}), {'f': 1.4276997320085631}),
#  (frozenset({'VENTALV', 'VENTLUNG'}), {'f': 1.123514132685413}),
#  (frozenset({'HYPOVOLEMIA', 'LVEDVOLUME', 'PCWP'}), {'f': 1.2282545747002882}),
#  (frozenset({'MINVOLSET', 'TPR'}), {'f': 1.4850142006653924}),
#  (frozenset({'EXPCO2', 'VENTLUNG'}), {'f': 1.0668581824402179}),
#  (frozenset({'PRESS', 'VENTTUBE'}), {'f': 1.7513389785588385}),
#  (frozenset({'ARTCO2', 'HR', 'HRSAT'}), {'f': 1.5852132603138058}),
#  (frozenset({'LVFAILURE', 'PRESS'}), {'f': 1.3188660765848335}),
#  (frozenset({'MINVOL', 'VENTTUBE'}), {'f': 1.3509291312524971}),
#  (frozenset({'HYPOVOLEMIA', 'VENTTUBE'}), {'f': 1.2758864842827398}),
#  (frozenset({'HRBP', 'PVSAT', 'VENTALV'}), {'f': 1.6713932403470302}),
#  (frozenset({'CO', 'HRBP'}), {'f': 1.3844522827307466}),
#  (frozenset({'DISCONNECT', 'VENTLUNG'}), {'f': 0.99111513560583486}),
#  (frozenset({'HR', 'HRBP', 'HRSAT'}), {'f': 1.2021076898827368}),
#  (frozenset({'PVSAT', 'STROKEVOLUME', 'VENTALV'}), {'f': 1.6433062859680005}),
#  (frozenset({'HRSAT', 'VENTMACH'}), {'f': 1.3711227869478622}),
#  (frozenset({'EXPCO2', 'PVSAT'}), {'f': 1.0944829268296261}),
#  (frozenset({'HR', 'HRSAT', 'VENTMACH'}), {'f': 1.5362395928988271}),
#  (frozenset({'DISCONNECT', 'STROKEVOLUME'}), {'f': 0.95979843832550671}),
#  (frozenset({'HRBP', 'TPR'}), {'f': 1.7409194303237043}),
#  (frozenset({'CO', 'HR', 'HRBP'}), {'f': 1.4634583183139271}),
#  (frozenset({'LVEDVOLUME', 'PCWP'}), {'f': 1.0114817366206081}),
#  (frozenset({'ERRLOWOUTPUT', 'LVFAILURE'}), {'f': 0.40023015825196084}),
#  (frozenset({'CO', 'VENTMACH'}), {'f': 1.5182048457976918}),
#  (frozenset({'DISCONNECT', 'HR'}), {'f': 0.85070096905912118}),
#  (frozenset({'KINKEDTUBE', 'SHUNT'}), {'f': 0.49916391954665745}),
#  (frozenset({'MINVOLSET', 'VENTALV', 'VENTLUNG'}), {'f': 1.432576451189584}),
#  (frozenset({'ARTCO2', 'VENTLUNG'}), {'f': 1.0883284682601799}),
#  (frozenset({'PVSAT', 'SAO2'}), {'f': 0.72759333287067718}),
#  (frozenset({'DISCONNECT', 'HRSAT'}), {'f': 1.0760207346249877}),
#  (frozenset({'LVFAILURE', 'VENTLUNG'}), {'f': 0.90211236656909666}),
#  (frozenset({'HREKG', 'HRSAT', 'PRESS'}), {'f': 2.1203182149536031}),
#  (frozenset({'INTUBATION', 'PRESS'}), {'f': 1.4245762071750452}),
#  (frozenset({'HYPOVOLEMIA', 'INTUBATION'}), {'f': 0.83335688478118841}),
#  (frozenset({'STROKEVOLUME', 'VENTALV', 'VENTLUNG'}),
#   {'f': 1.7582280620919453}),
#  (frozenset({'INTUBATION', 'MINVOL'}), {'f': 1.0779203591616173}),
#  (frozenset({'HRBP', 'HREKG'}), {'f': 1.1354381760472214}),
#  (frozenset({'ANAPHYLAXIS', 'HR'}), {'f': 0.58276440412162023}),
#  (frozenset({'PVSAT', 'SHUNT', 'VENTALV'}), {'f': 1.2873706350595846}),
#  (frozenset({'LVEDVOLUME'}), {'f': 0.79089467543430259}),
#  (frozenset({'HREKG', 'HRSAT'}), {'f': 1.0014340013926355}),
#  (frozenset({'CATECHOL', 'PCWP'}), {'f': 1.166285878942585}),
#  (frozenset({'ANAPHYLAXIS', 'PVSAT', 'VENTALV'}), {'f': 1.0630506525419756}),
#  (frozenset({'ARTCO2', 'INSUFFANESTH'}), {'f': 1.0199918153309016}),
#  (frozenset({'LVFAILURE', 'PULMEMBOLUS'}), {'f': 0.25460880137193626}),
#  (frozenset({'ERRCAUTER', 'PVSAT', 'VENTALV'}), {'f': 1.3288127198647626}),
#  (frozenset({'ARTCO2', 'ERRLOWOUTPUT'}), {'f': 0.89290444186118756}),
#  (frozenset({'BP', 'HREKG', 'HRSAT'}), {'f': 2.0383661330086826}),
#  (frozenset({'LVEDVOLUME', 'VENTTUBE'}), {'f': 1.5666514114369177}),
#  (frozenset({'ANAPHYLAXIS', 'VENTMACH'}), {'f': 0.67771870940166701}),
#  (frozenset({'FIO2', 'KINKEDTUBE'}), {'f': 0.3677318957018792}),
#  (frozenset({'ARTCO2', 'VENTALV', 'VENTMACH'}), {'f': 1.5580944580270462}),
#  (frozenset({'HRBP', 'INTUBATION'}), {'f': 1.0175210138007573}),
#  (frozenset({'DISCONNECT', 'INSUFFANESTH'}), {'f': 0.65321902536327603}),
#  (frozenset({'PAP', 'VENTMACH'}), {'f': 1.0360216423171889}),
#  (frozenset({'HRBP', 'VENTMACH'}), {'f': 1.3020411340771125}),
#  (frozenset({'CVP', 'HISTORY', 'LVEDVOLUME'}), {'f': 1.2223009129401641}),
#  (frozenset({'BP', 'HRBP'}), {'f': 1.7219705576641993}),
#  (frozenset({'HREKG', 'STROKEVOLUME'}), {'f': 1.3911253153398282}),
#  (frozenset({'CATECHOL', 'CVP'}), {'f': 1.0959295965521525}),
#  (frozenset({'ARTCO2'}), {'f': 0.69175443559952265}),
#  (frozenset({'INSUFFANESTH', 'VENTALV'}), {'f': 1.2238093639284362}),
#  (frozenset({'EXPCO2', 'MINVOLSET'}), {'f': 0.93014863897749434}),
#  (frozenset({'MINVOL', 'VENTMACH'}), {'f': 1.3393417422300544}),
#  (frozenset({'LVEDVOLUME', 'VENTALV'}), {'f': 1.6864933046995207}),
#  (frozenset({'ARTCO2', 'ERRCAUTER'}), {'f': 1.0120508712135572}),
#  (frozenset({'HYPOVOLEMIA', 'MINVOLSET'}), {'f': 0.89573659129295391}),
#  (frozenset({'PCWP', 'SAO2'}), {'f': 1.4324931800461849}),
#  (frozenset({'ERRLOWOUTPUT', 'SAO2'}), {'f': 0.79593538702270028}),
#  (frozenset({'KINKEDTUBE', 'MINVOL'}), {'f': 1.0035263014443525}),
#  (frozenset({'ERRLOWOUTPUT', 'STROKEVOLUME'}), {'f': 0.83597637914525214}),
#  (frozenset({'HR', 'HRBP', 'PVSAT'}), {'f': 1.3600363286975503}),
#  (frozenset({'EXPCO2', 'PULMEMBOLUS'}), {'f': 0.59718303846759446}),
#  (frozenset({'BP', 'ERRCAUTER'}), {'f': 1.3798618677117311}),
#  (frozenset({'PCWP', 'PVSAT', 'SAO2'}), {'f': 1.5652384059157838}),
#  (frozenset({'ERRCAUTER', 'PAP'}), {'f': 0.73313914923694357}),
#  (frozenset({'PCWP', 'PVSAT', 'VENTALV'}), {'f': 1.8461214215326001}),
#  (frozenset({'ERRLOWOUTPUT', 'HREKG'}), {'f': 0.95747542835279509}),
#  (frozenset({'KINKEDTUBE', 'PCWP'}), {'f': 1.0047256384899215}),
#  (frozenset({'BP', 'CATECHOL'}), {'f': 1.3679034021115779}),
#  (frozenset({'LVFAILURE', 'VENTALV'}), {'f': 1.094667096020902}),
#  (frozenset({'PAP', 'PRESS'}), {'f': 1.5326329941151517}),
#  (frozenset({'HR', 'HRSAT', 'PULMEMBOLUS'}), {'f': 0.9750419945153187}),
#  (frozenset({'PAP', 'PCWP'}), {'f': 1.2504985987529209}),
#  (frozenset({'MINVOLSET', 'VENTTUBE'}), {'f': 0.9664791852716994}),
#  (frozenset({'CATECHOL', 'SHUNT'}), {'f': 0.66070306998337347}),
#  (frozenset({'PVSAT', 'VENTALV', 'VENTTUBE'}), {'f': 1.5220753897198929}),
#  (frozenset({'CVP', 'LVEDVOLUME', 'VENTTUBE'}), {'f': 1.8821296442742597}),
#  (frozenset({'PVSAT', 'TPR', 'VENTALV'}), {'f': 2.0978213374812431}),
#  (frozenset({'EXPCO2', 'PVSAT', 'VENTALV'}), {'f': 1.4316944345708502}),
#  (frozenset({'BP', 'MINVOL'}), {'f': 1.9003758529947685}),
#  (frozenset({'HRBP', 'SAO2'}), {'f': 1.2617748972404355}),
#  (frozenset({'ARTCO2', 'PRESS'}), {'f': 1.7913396447271244}),
#  (frozenset({'HISTORY', 'VENTTUBE'}), {'f': 0.98707305792160249}),
#  (frozenset({'FIO2', 'HR', 'HRBP'}), {'f': 1.0116967290017784}),
#  (frozenset({'CATECHOL', 'INSUFFANESTH'}), {'f': 0.65675357123953271}),
#  (frozenset({'TPR', 'VENTALV'}), {'f': 1.9849863755287867}),
#  (frozenset({'ANAPHYLAXIS', 'TPR'}), {'f': 1.1337151421513079}),
#  (frozenset({'MINVOL', 'MINVOLSET'}), {'f': 1.1617792035282763}),
#  (frozenset({'ERRLOWOUTPUT', 'FIO2'}), {'f': 0.40187245794091336}),
#  (frozenset({'HREKG', 'MINVOL', 'VENTALV'}), {'f': 1.9436085132404115}),
#  (frozenset({'BP', 'MINVOLSET'}), {'f': 1.4546902345597896}),
#  (frozenset({'STROKEVOLUME', 'VENTLUNG'}), {'f': 1.3378601633810165}),
#  (frozenset({'ARTCO2', 'HRSAT', 'VENTALV'}), {'f': 1.792404105031455}),
#  (frozenset({'CVP', 'LVEDVOLUME', 'SAO2'}), {'f': 1.701214130410885}),
#  (frozenset({'KINKEDTUBE'}), {'f': 0.16702141745855753}),
#  (frozenset({'ANAPHYLAXIS', 'HR', 'HRSAT'}), {'f': 0.97384635250246421}),
#  (frozenset({'HRSAT', 'PVSAT', 'SAO2'}), {'f': 1.46329163314572}),
#  (frozenset({'CATECHOL', 'HISTORY'}), {'f': 0.53986313991105128}),
#  (frozenset({'HRSAT', 'INTUBATION'}), {'f': 1.0864209057704728}),
#  (frozenset({'ANAPHYLAXIS', 'CO'}), {'f': 0.95324356981374359}),
#  (frozenset({'ERRCAUTER', 'HREKG'}), {'f': 0.86367957598473144}),
#  (frozenset({'DISCONNECT', 'PVSAT', 'VENTALV'}), {'f': 1.2891303724494672}),
#  (frozenset({'HR', 'INSUFFANESTH'}), {'f': 0.85659952403650286}),
#  (frozenset({'CVP', 'LVEDVOLUME', 'VENTMACH'}), {'f': 1.7295380050703273}),
#  (frozenset({'ARTCO2', 'CO', 'VENTALV'}), {'f': 1.9449158252446523}),
#  (frozenset({'ANAPHYLAXIS', 'LVFAILURE'}), {'f': 0.25359944742642915}),
#  (frozenset({'ERRCAUTER', 'VENTTUBE'}), {'f': 1.0960834722663524}),
#  (frozenset({'CVP', 'LVFAILURE'}), {'f': 0.86863735701246614}),
#  (frozenset({'LVEDVOLUME', 'SHUNT'}), {'f': 1.1230380366990631}),
#  (frozenset({'PAP', 'TPR'}), {'f': 1.5022374561844076}),
#  (frozenset({'MINVOL', 'PULMEMBOLUS', 'VENTALV'}), {'f': 1.2628332525516881}),
#  (frozenset({'ARTCO2', 'HR', 'HRBP'}), {'f': 1.476700439851119}),
#  (frozenset({'LVEDVOLUME', 'PVSAT', 'VENTALV'}), {'f': 1.7993169304034875}),
#  (frozenset({'LVEDVOLUME', 'PCWP', 'VENTLUNG'}), {'f': 1.7144314964993732}),
#  (frozenset({'HREKG', 'SHUNT'}), {'f': 1.0884488749574048}),
#  (frozenset({'ERRCAUTER', 'LVEDVOLUME', 'PCWP'}), {'f': 1.33168283085767}),
#  (frozenset({'DISCONNECT', 'MINVOL', 'VENTALV'}), {'f': 1.483231678981511}),
#  (frozenset({'PCWP', 'VENTALV'}), {'f': 1.7333061429142878}),
#  (frozenset({'PVSAT'}), {'f': 0.57011147120866412}),
#  (frozenset({'BP', 'PVSAT', 'VENTALV'}), {'f': 2.0654004309643197}),
#  (frozenset({'ANAPHYLAXIS', 'PRESS'}), {'f': 1.1743161034122598}),
#  (frozenset({'PRESS'}), {'f': 1.1198018766744218}),
#  (frozenset({'DISCONNECT', 'LVFAILURE'}), {'f': 0.5240435275307268}),
#  (frozenset({'HRSAT', 'VENTLUNG'}), {'f': 1.4423179859749597}),
#  (frozenset({'ERRLOWOUTPUT', 'PCWP'}), {'f': 1.0388779386790661}),
#  (frozenset({'HRSAT', 'PULMEMBOLUS'}), {'f': 0.80889937949169333}),
#  (frozenset({'DISCONNECT', 'HR', 'HRBP'}), {'f': 1.1333082635676837}),
#  (frozenset({'INTUBATION', 'PCWP'}), {'f': 1.1709622568768776}),
#  (frozenset({'INSUFFANESTH', 'KINKEDTUBE'}), {'f': 0.49527456535521702}),
#  (frozenset({'INTUBATION', 'LVEDVOLUME', 'PCWP'}), {'f': 1.3446664086806752}),
#  (frozenset({'HISTORY', 'STROKEVOLUME'}), {'f': 0.78934361808186926}),
#  (frozenset({'INSUFFANESTH', 'PVSAT', 'SAO2'}), {'f': 1.0557915288796111}),
#  (frozenset({'HR', 'VENTMACH'}), {'f': 1.1451370983128213}),
#  (frozenset({'ERRCAUTER', 'INTUBATION'}), {'f': 0.65354944247339641}),
#  (frozenset({'EXPCO2', 'TPR'}), {'f': 1.6310172658165476}),
#  (frozenset({'DISCONNECT', 'SAO2'}), {'f': 0.88837694911778831}),
#  (frozenset({'CO', 'PRESS'}), {'f': 2.0181381760691224}),
#  (frozenset({'CVP', 'DISCONNECT', 'LVEDVOLUME'}), {'f': 1.4314566022959248}),
#  (frozenset({'CVP', 'HR'}), {'f': 1.2957477710849488}),
#  (frozenset({'KINKEDTUBE', 'PULMEMBOLUS'}), {'f': 0.22256288224062026}),
#  (frozenset({'CATECHOL', 'PRESS'}), {'f': 1.4458077439406813}),
#  (frozenset({'ERRLOWOUTPUT', 'LVEDVOLUME', 'PCWP'}), {'f': 1.212614418406287}),
#  (frozenset({'EXPCO2', 'HR', 'HRSAT'}), {'f': 1.458990182515755}),
#  (frozenset({'PVSAT', 'VENTMACH'}), {'f': 1.0908093165745061}),
#  (frozenset({'MINVOL'}), {'f': 0.84292486108822906}),
#  (frozenset({'HREKG', 'HRSAT', 'PVSAT'}), {'f': 1.5528364011408335}),
#  (frozenset({'EXPCO2', 'HR', 'HRBP'}), {'f': 1.3503644490407976}),
#  (frozenset({'INTUBATION', 'PVSAT'}), {'f': 0.89495900010127305}),
#  (frozenset({'HREKG', 'HRSAT', 'VENTMACH'}), {'f': 1.6186354200874942}),
#  (frozenset({'CVP', 'HRSAT', 'LVEDVOLUME'}), {'f': 1.8597202778860547}),
#  (frozenset({'ERRCAUTER', 'PCWP'}), {'f': 1.1580041841830897}),
#  (frozenset({'ERRLOWOUTPUT', 'HRSAT'}), {'f': 0.95451135022117972}),
#  (frozenset({'INTUBATION', 'PAP'}), {'f': 0.74606922591859881}),
#  (frozenset({'ARTCO2', 'SAO2'}), {'f': 0.96914950327784866}),
#  (frozenset({'HR', 'PCWP'}), {'f': 1.3661051960411219}),
#  (frozenset({'DISCONNECT', 'VENTALV'}), {'f': 1.1762276240517175}),
#  (frozenset({'PVSAT', 'VENTALV'}), {'f': 1.0085435615970249}),
#  (frozenset({'ANAPHYLAXIS', 'VENTALV', 'VENTLUNG'}),
#   {'f': 1.1779779158116561}),
#  (frozenset({'FIO2', 'INTUBATION'}), {'f': 0.5339658139412411}),
#  (frozenset({'CVP', 'LVEDVOLUME', 'LVFAILURE'}), {'f': 1.1760705555312012}),
#  (frozenset({'ANAPHYLAXIS', 'PAP'}), {'f': 0.46734991276962867}),
#  (frozenset({'BP', 'LVEDVOLUME'}), {'f': 1.8365062142845647}),
#  (frozenset({'PCWP', 'SHUNT'}), {'f': 1.1698682955980708}),
#  (frozenset({'HREKG', 'LVEDVOLUME'}), {'f': 1.5471750602690042}),
#  (frozenset({'KINKEDTUBE', 'MINVOLSET'}), {'f': 0.56264336791592595}),
#  (frozenset({'BP', 'FIO2'}), {'f': 1.2602644388308173}),
#  (frozenset({'CVP', 'KINKEDTUBE', 'LVEDVOLUME'}), {'f': 1.2734941087276948}),
#  (frozenset({'HREKG', 'VENTALV'}), {'f': 1.6319511667131845}),
#  (frozenset({'ARTCO2', 'TPR'}), {'f': 1.7811455768198141}),
#  (frozenset({'CATECHOL', 'FIO2'}), {'f': 0.52927748904513927}),
#  (frozenset({'DISCONNECT', 'VENTTUBE'}), {'f': 0.93217823798420762}),
#  (frozenset({'HREKG', 'INTUBATION'}), {'f': 1.0893247828966097}),
#  (frozenset({'BP', 'EXPCO2'}), {'f': 1.6008787398033331}),
#  (frozenset({'ERRCAUTER', 'HRBP'}), {'f': 1.0047682955479424}),
#  (frozenset({'ERRCAUTER', 'TPR'}), {'f': 1.4097108337226645}),
#  (frozenset({'HYPOVOLEMIA', 'KINKEDTUBE'}), {'f': 0.66713247774403905}),
#  (frozenset({'INTUBATION', 'STROKEVOLUME'}), {'f': 0.96804962566076136}),
#  (frozenset({'FIO2', 'HR'}), {'f': 0.72909403047349619}),
#  (frozenset({'CATECHOL', 'DISCONNECT'}), {'f': 0.64809768732479689}),
#  (frozenset({'FIO2', 'PVSAT'}), {'f': 0.75045489976356228}),
#  (frozenset({'SHUNT', 'STROKEVOLUME'}), {'f': 0.96696971404113097}),
#  (frozenset({'CATECHOL', 'HREKG'}), {'f': 0.95020539788433389}),
#  (frozenset({'HYPOVOLEMIA', 'PVSAT', 'SAO2'}), {'f': 1.2276511234516869}),
#  (frozenset({'STROKEVOLUME'}), {'f': 0.6348257518542153}),
#  (frozenset({'HR', 'PVSAT', 'VENTALV'}), {'f': 1.5123754146752044}),
#  (frozenset({'PRESS', 'VENTMACH'}), {'f': 1.670738709597579}),
#  (frozenset({'ANAPHYLAXIS', 'PULMEMBOLUS'}), {'f': 0.11006452229855472}),
#  (frozenset({'CO', 'SHUNT'}), {'f': 1.23088670092109}),
#  (frozenset({'HRSAT', 'PRESS'}), {'f': 1.872348700801715}),
#  (frozenset({'PVSAT', 'SAO2', 'VENTTUBE'}), {'f': 1.2953613978507061}),
#  (frozenset({'HR', 'HREKG'}), {'f': 0.92386323754206412}),
#  (frozenset({'ERRLOWOUTPUT', 'HRBP'}), {'f': 0.7586197111327827}),
#  (frozenset({'BP', 'HISTORY'}), {'f': 1.2603988622242783}),
#  (frozenset({'HYPOVOLEMIA', 'PULMEMBOLUS'}), {'f': 0.5556463596722887}),
#  (frozenset({'CO', 'HREKG', 'HRSAT'}), {'f': 1.6920914898321671}),
#  (frozenset({'ERRCAUTER', 'LVEDVOLUME'}), {'f': 1.1111539620423583}),
#  (frozenset({'HREKG', 'HRSAT', 'LVFAILURE'}), {'f': 1.200384185053595}),
#  (frozenset({'HR', 'LVEDVOLUME'}), {'f': 1.3192749700189912}),
#  (frozenset({'ERRLOWOUTPUT', 'HR', 'HRBP'}), {'f': 0.85883554641446491}),
#  (frozenset({'HR', 'HRSAT', 'PAP'}), {'f': 1.3322454085087612}),
#  (frozenset({'ARTCO2', 'INTUBATION'}), {'f': 0.99264925155425998}),
#  (frozenset({'HR', 'HRSAT', 'LVEDVOLUME'}), {'f': 1.7103551913142316}),
#  (frozenset({'KINKEDTUBE', 'SAO2'}), {'f': 0.75715540407026438}),
#  (frozenset({'HR', 'PULMEMBOLUS'}), {'f': 0.58390435867169854}),
#  (frozenset({'HR', 'HRBP', 'PCWP'}), {'f': 1.6486477135494895}),
#  (frozenset({'CO', 'CVP'}), {'f': 1.6240696670710479}),
#  (frozenset({'INTUBATION', 'SAO2'}), {'f': 0.91845534138946427}),
#  (frozenset({'INSUFFANESTH', 'SHUNT'}), {'f': 0.66038007882404515}),
#  (frozenset({'HYPOVOLEMIA', 'STROKEVOLUME'}), {'f': 1.0509573872282396}),
#  (frozenset({'HR', 'LVEDVOLUME', 'PCWP'}), {'f': 1.5398200018231296}),
#  (frozenset({'MINVOL', 'PVSAT', 'VENTALV'}), {'f': 1.3202827801525556}),
#  (frozenset({'ANAPHYLAXIS', 'SAO2'}), {'f': 0.64931488367275392}),
#  (frozenset({'CATECHOL', 'EXPCO2'}), {'f': 0.86622114374413983}),
#  (frozenset({'ERRLOWOUTPUT', 'HYPOVOLEMIA'}), {'f': 0.70126776479426811}),
#  (frozenset({'HREKG', 'PVSAT', 'SAO2'}), {'f': 1.4664110904285794}),
#  (frozenset({'CATECHOL', 'ERRCAUTER'}), {'f': 0.64887337147458524}),
#  (frozenset({'CO', 'HR'}), {'f': 1.1809091696105429}),
#  (frozenset({'HRSAT', 'PVSAT', 'VENTALV'}), {'f': 1.7416283111187369}),
#  (frozenset({'ERRLOWOUTPUT', 'PRESS'}), {'f': 1.3209348403386314}),
#  (frozenset({'CATECHOL', 'LVEDVOLUME', 'PCWP'}), {'f': 1.3400227069443942}),
#  (frozenset({'HREKG', 'KINKEDTUBE'}), {'f': 0.92321024366983306}),
#  (frozenset({'HREKG', 'HRSAT', 'LVEDVOLUME'}), {'f': 1.7922000251619457}),
#  (frozenset({'MINVOLSET', 'SHUNT'}), {'f': 0.72776854009006886}),
#  (frozenset({'KINKEDTUBE', 'VENTALV', 'VENTLUNG'}), {'f': 1.2820179805203591}),
#  (frozenset({'HR', 'HRBP', 'VENTLUNG'}), {'f': 1.496694496875649}),
#  (frozenset({'EXPCO2', 'FIO2'}), {'f': 0.74236025756949386}),
#  (frozenset({'HISTORY', 'SHUNT'}), {'f': 0.54344446989915174}),
#  (frozenset({'LVEDVOLUME', 'LVFAILURE', 'PCWP'}), {'f': 1.0810564798418794}),
#  (frozenset({'CATECHOL', 'VENTTUBE'}), {'f': 1.0781737405452647}),
#  (frozenset({'ERRLOWOUTPUT'}), {'f': 0.20115676277173083}),
#  (frozenset({'ANAPHYLAXIS', 'DISCONNECT'}), {'f': 0.37949415318647345}),
#  (frozenset({'BP', 'INSUFFANESTH'}), {'f': 1.3878054831987361}),
#  (frozenset({'ANAPHYLAXIS', 'PVSAT'}), {'f': 0.62463718179956651}),
#  (frozenset({'HRSAT', 'VENTALV', 'VENTLUNG'}), {'f': 1.8566691352445404}),
#  (frozenset({'ARTCO2', 'STROKEVOLUME'}), {'f': 1.3265733191035027}),
#  (frozenset({'INTUBATION', 'MINVOL', 'VENTALV'}), {'f': 1.3512822590740303}),
#  (frozenset({'CVP', 'VENTLUNG'}), {'f': 1.4703916806401465}),
#  (frozenset({'HISTORY', 'LVFAILURE'}), {'f': 0.26725720819142718}),
#  (frozenset({'HISTORY', 'TPR'}), {'f': 1.3007217375757003}),
#  (frozenset({'CO', 'PVSAT'}), {'f': 1.4573256672906831}),
#  (frozenset({'PULMEMBOLUS', 'VENTALV', 'VENTLUNG'}),
#   {'f': 1.1789883712054876}),
#  (frozenset({'PVSAT', 'SAO2', 'VENTMACH'}), {'f': 1.2481500507477397}),
#  (frozenset({'PRESS', 'VENTLUNG'}), {'f': 1.7835758262268613}),
#  (frozenset({'CVP', 'MINVOLSET'}), {'f': 1.162988268400869}),
#  (frozenset({'HISTORY'}), {'f': 0.21130096726561731}),
#  (frozenset({'ANAPHYLAXIS', 'HRBP'}), {'f': 0.73888848817143049}),
#  (frozenset({'HISTORY', 'HR', 'HRSAT'}), {'f': 1.130766742064061}),
#  (frozenset({'MINVOLSET', 'PAP'}), {'f': 0.8084299137406229}),
#  (frozenset({'ARTCO2', 'PAP', 'VENTALV'}), {'f': 1.4732669499003597}),
#  (frozenset({'CVP', 'INSUFFANESTH', 'LVEDVOLUME'}), {'f': 1.4347251633399551}),
#  (frozenset({'INSUFFANESTH', 'VENTTUBE'}), {'f': 1.1040081622210176}),
#  (frozenset({'ERRLOWOUTPUT', 'MINVOL', 'VENTALV'}), {'f': 1.4085249312534844}),
#  (frozenset({'ERRLOWOUTPUT', 'LVEDVOLUME'}), {'f': 0.99204951908241779}),
#  (frozenset({'CATECHOL', 'INTUBATION'}), {'f': 0.66130749044729864}),
#  (frozenset({'MINVOL', 'PULMEMBOLUS'}), {'f': 0.8984262857188825}),
#  (frozenset({'HISTORY', 'SAO2'}), {'f': 0.80609019635202162}),
#  (frozenset({'INTUBATION', 'MINVOLSET'}), {'f': 0.72884339235659068}),
#  (frozenset({'TPR'}), {'f': 1.0894212316806815}),
#  (frozenset({'HREKG', 'HRSAT', 'PAP'}), {'f': 1.4141950142200517}),
#  (frozenset({'LVEDVOLUME', 'MINVOL'}), {'f': 1.6338017649161056}),
#  (frozenset({'CVP', 'HRBP'}), {'f': 1.4518139740848459}),
#  (frozenset({'HYPOVOLEMIA', 'PCWP'}), {'f': 1.0899619885065448}),
#  (frozenset({'ANAPHYLAXIS', 'MINVOLSET'}), {'f': 0.450137435723788}),
#  (frozenset({'CATECHOL', 'HRBP'}), {'f': 0.86582393346947961}),
#  (frozenset({'PCWP', 'PRESS'}), {'f': 1.957507897355433}),
#  (frozenset({'ERRCAUTER', 'VENTLUNG'}), {'f': 1.0233455358407026}),
#  (frozenset({'FIO2', 'HRBP'}), {'f': 0.88517466454929128}),
#  (frozenset({'ERRLOWOUTPUT', 'VENTALV', 'VENTLUNG'}),
#   {'f': 1.3245760372518829}),
#  (frozenset({'PRESS', 'SAO2'}), {'f': 1.6984386688089843}),
#  (frozenset({'BP', 'PRESS'}), {'f': 2.1792830418297009}),
#  (frozenset({'HRBP', 'VENTLUNG'}), {'f': 1.3723101684337031}),
#  (frozenset({'LVEDVOLUME', 'MINVOLSET'}), {'f': 1.1865071655566903}),
#  (frozenset({'TPR', 'VENTTUBE'}), {'f': 1.8651424819506512}),
#  (frozenset({'HRSAT', 'PVSAT'}), {'f': 1.3060806378256258}),
#  (frozenset({'CVP', 'VENTTUBE'}), {'f': 1.5431319746981442}),
#  (frozenset({'HR', 'HRSAT'}), {'f': 0.91953607361798162}),
#  (frozenset({'LVEDVOLUME', 'PAP', 'PCWP'}), {'f': 1.4242260180944804}),
#  (frozenset({'HRBP', 'PVSAT'}), {'f': 1.2361295149053355}),
#  (frozenset({'CVP', 'SAO2'}), {'f': 1.3621555845895303}),
#  (frozenset({'HISTORY', 'LVEDVOLUME'}), {'f': 0.9067105829858132}),
#  (frozenset({'HREKG', 'HRSAT', 'PULMEMBOLUS'}), {'f': 1.0569614979667366}),
#  (frozenset({'ARTCO2', 'MINVOL'}), {'f': 1.178983185767746}),
#  (frozenset({'HR', 'HRSAT', 'HYPOVOLEMIA'}), {'f': 1.4196319079959803}),
#  (frozenset({'INSUFFANESTH'}), {'f': 0.32825732002909813}),
#  (frozenset({'CO', 'STROKEVOLUME'}), {'f': 1.2201954631070722}),
#  (frozenset({'HYPOVOLEMIA', 'LVFAILURE'}), {'f': 0.69918305688168669}),
#  (frozenset({'HR', 'HRSAT', 'VENTALV'}), {'f': 1.7907272024782854}),
#  (frozenset({'EXPCO2', 'SAO2'}), {'f': 1.1215038237611235}),
#  (frozenset({'CVP', 'HYPOVOLEMIA'}), {'f': 1.1145684876406816}),
#  (frozenset({'HRSAT', 'HYPOVOLEMIA'}), {'f': 1.2534642802649441}),
#  (frozenset({'HYPOVOLEMIA', 'TPR'}), {'f': 1.589529576143992}),
#  (frozenset({'HRBP', 'LVEDVOLUME'}), {'f': 1.4753507526575533}),
#  (frozenset({'LVEDVOLUME', 'PCWP', 'SAO2'}), {'f': 1.6062103436307278}),
#  (frozenset({'ERRLOWOUTPUT', 'VENTLUNG'}), {'f': 0.90416600875391817}),
#  (frozenset({'ARTCO2', 'ERRCAUTER', 'VENTALV'}), {'f': 1.380803714574256}),
#  (frozenset({'CO', 'HREKG'}), {'f': 1.4681031689773596}),
#  (frozenset({'ARTCO2', 'BP', 'VENTALV'}), {'f': 2.1171902132565479}),
#  (frozenset({'CO', 'PVSAT', 'SAO2'}), {'f': 1.6145874282413684}),
#  (frozenset({'INSUFFANESTH', 'VENTLUNG'}), {'f': 1.0312728637567177}),
#  (frozenset({'ANAPHYLAXIS', 'HRSAT'}), {'f': 0.80778839686093928}),
#  (frozenset({'HRSAT', 'MINVOLSET'}), {'f': 1.1457833936617443}),
#  (frozenset({'DISCONNECT', 'SHUNT'}), {'f': 0.65711731240248461}),
#  (frozenset({'SHUNT', 'VENTTUBE'}), {'f': 1.1079145600506113}),
#  (frozenset({'PAP', 'STROKEVOLUME'}), {'f': 1.0476476096202785}),
#  (frozenset({'ERRCAUTER', 'STROKEVOLUME'}), {'f': 0.95513067509852467}),
#  (frozenset({'PCWP', 'VENTTUBE'}), {'f': 1.6134647098205364}),
#  (frozenset({'LVEDVOLUME', 'PCWP', 'VENTTUBE'}), {'f': 1.7871408984464725}),
#  (frozenset({'CVP', 'EXPCO2'}), {'f': 1.3090026376157697}),
#  (frozenset({'BP', 'ERRLOWOUTPUT'}), {'f': 1.2607025644336078}),
#  (frozenset({'CVP', 'HRBP', 'LVEDVOLUME'}), {'f': 1.790922194195798}),
#  (frozenset({'ARTCO2', 'HREKG', 'HRSAT'}), {'f': 1.6701427217385807}),
#  (frozenset({'HR', 'HRBP', 'SAO2'}), {'f': 1.3859469251407543}),
#  (frozenset({'ARTCO2', 'SHUNT', 'VENTALV'}), {'f': 1.3393619146223434}),
#  (frozenset({'HR', 'HRBP', 'TPR'}), {'f': 1.8629526805791417}),
#  (frozenset({'EXPCO2', 'PRESS'}), {'f': 1.649410503882754}),
#  (frozenset({'CO', 'FIO2'}), {'f': 1.0994504890987646}),
#  (frozenset({'FIO2', 'SAO2'}), {'f': 0.78023253003499804}),
#  (frozenset({'ARTCO2', 'DISCONNECT', 'VENTALV'}), {'f': 1.3411171774788024}),
#  (frozenset({'HREKG', 'PRESS'}), {'f': 1.8754149769530559}),
#  (frozenset({'HREKG', 'HRSAT', 'SAO2'}), {'f': 1.5786784070736715}),
#  (frozenset({'HRBP', 'HRSAT'}), {'f': 1.1315951192365903}),
#  (frozenset({'PRESS', 'VENTALV', 'VENTLUNG'}), {'f': 2.1807281783444354}),
#  (frozenset({'HISTORY', 'PVSAT', 'SAO2'}), {'f': 0.938867153986369}),
#  (frozenset({'PCWP', 'VENTALV', 'VENTLUNG'}), {'f': 1.9611247529524378}),
#  (frozenset({'HYPOVOLEMIA', 'LVEDVOLUME'}), {'f': 1.0076792848430949}),
#  (frozenset({'LVFAILURE', 'PAP'}), {'f': 0.61189321959333742}),
#  (frozenset({'BP', 'LVFAILURE'}), {'f': 1.2434864874997447}),
#  (frozenset({'HYPOVOLEMIA', 'INSUFFANESTH'}), {'f': 0.82836635955647564}),
#  (frozenset({'INTUBATION', 'TPR'}), {'f': 1.4225992992972007}),
#  (frozenset({'ANAPHYLAXIS', 'LVEDVOLUME'}), {'f': 0.84541851228181553}),
#  (frozenset({'INSUFFANESTH', 'VENTALV', 'VENTLUNG'}),
#   {'f': 1.4516476270882397}),
#  (frozenset({'HR'}), {'f': 0.52838223694766295}),
#  (frozenset({'PULMEMBOLUS', 'SHUNT'}), {'f': 0.36990262454895301}),
#  (frozenset({'MINVOLSET', 'STROKEVOLUME'}), {'f': 1.0304401524855977}),
#  (frozenset({'HR', 'HRBP', 'PULMEMBOLUS'}), {'f': 0.86649843509108493}),
#  (frozenset({'SHUNT', 'VENTALV', 'VENTLUNG'}), {'f': 1.3706469832318482}),
#  (frozenset({'CVP', 'EXPCO2', 'LVEDVOLUME'}), {'f': 1.6480060948929496}),
#  (frozenset({'LVEDVOLUME', 'MINVOL', 'VENTALV'}), {'f': 1.9981993530669724}),
#  (frozenset({'HREKG', 'HRSAT', 'VENTALV'}), {'f': 1.8753374701020336}),
#  (frozenset({'STROKEVOLUME', 'VENTMACH'}), {'f': 1.2580309893602157}),
#  (frozenset({'CATECHOL', 'MINVOL', 'VENTALV'}), {'f': 1.4836574617876495}),
#  (frozenset({'ARTCO2', 'DISCONNECT'}), {'f': 0.98092408059433922}),
#  (frozenset({'SAO2', 'VENTMACH'}), {'f': 1.1293175861817393}),
#  (frozenset({'ANAPHYLAXIS', 'MINVOL', 'VENTALV'}), {'f': 1.2618947502243238}),
#  (frozenset({'ERRLOWOUTPUT', 'VENTTUBE'}), {'f': 0.97690345082208263}),
#  (frozenset({'ARTCO2', 'EXPCO2'}), {'f': 1.1847869327551321}),
#  (frozenset({'LVFAILURE', 'VENTALV', 'VENTLUNG'}), {'f': 1.3225180664589673}),
#  (frozenset({'HISTORY', 'VENTLUNG'}), {'f': 0.91434174921055122}),
#  (frozenset({'EXPCO2', 'LVEDVOLUME', 'PCWP'}), {'f': 1.5530282464729785}),
#  (frozenset({'HISTORY', 'PULMEMBOLUS'}), {'f': 0.26682153013432514}),
#  (frozenset({'HRBP', 'STROKEVOLUME'}), {'f': 1.3192542072402669}),
#  (frozenset({'LVEDVOLUME', 'SAO2'}), {'f': 1.3856768749559571}),
# ...
#  (frozenset({'HR', 'SAO2'}), {'f': 1.1033612144182237}),
#  (frozenset({'LVEDVOLUME', 'MINVOLSET', 'PCWP'}), {'f': 1.4070428323915674}),
#  (frozenset({'ARTCO2', 'LVEDVOLUME'}), {'f': 1.4826483957410703}),
#  (frozenset({'CVP', 'ERRCAUTER', 'LVEDVOLUME'}), {'f': 1.4267464107070138}),
#  (frozenset({'ANAPHYLAXIS', 'VENTLUNG'}), {'f': 0.75756705960930881}),
#  (frozenset({'BP', 'HR', 'HRBP'}), {'f': 1.8422569506344242}),
#  (frozenset({'HR', 'KINKEDTUBE'}), {'f': 0.69521073802677169}),
#  (frozenset({'FIO2', 'HYPOVOLEMIA'}), {'f': 0.70082776080414466}),
#  (frozenset({'DISCONNECT', 'INTUBATION'}), {'f': 0.65822280737252781}),
#  (frozenset({'HISTORY', 'PVSAT', 'VENTALV'}), {'f': 1.2197856932036231}),
#  (frozenset({'LVEDVOLUME', 'PULMEMBOLUS'}), {'f': 0.84643103597109814}),
#  (frozenset({'CVP', 'ERRLOWOUTPUT'}), {'f': 0.96852387564084763}),
#  (frozenset({'EXPCO2', 'HREKG'}), {'f': 1.2962338454523292}),
#  (frozenset({'ANAPHYLAXIS', 'ARTCO2'}), {'f': 0.746278633253742}),
#  (frozenset({'LVEDVOLUME', 'VENTLUNG'}), {'f': 1.4939218676556971}),
#  (frozenset({'HR', 'HRBP', 'LVEDVOLUME'}), {'f': 1.6018217116395497}),
#  (frozenset({'PRESS', 'PVSAT'}), {'f': 1.6703172159507129}),
#  (frozenset({'ANAPHYLAXIS'}), {'f': 0.054525873325282463}),
#  (frozenset({'FIO2', 'HISTORY'}), {'f': 0.412015847997941}),
#  (frozenset({'HYPOVOLEMIA', 'PVSAT'}), {'f': 1.0702219932029835}),
#  (frozenset({'DISCONNECT', 'HYPOVOLEMIA'}), {'f': 0.82508315106549601}),
#  (frozenset({'INSUFFANESTH', 'MINVOL', 'VENTALV'}), {'f': 1.5355748189135321}),
#  (frozenset({'ARTCO2', 'PVSAT', 'SAO2'}), {'f': 1.0388056396709535}),
#  (frozenset({'HRSAT', 'PAP'}), {'f': 1.1661839082326664}),
#  (frozenset({'HREKG', 'HYPOVOLEMIA'}), {'f': 1.2564255751370641}),
#  (frozenset({'BP', 'HRSAT'}), {'f': 1.7919484233776577}),
#  (frozenset({'HRBP', 'LVFAILURE'}), {'f': 0.883536305415208}),
#  (frozenset({'HYPOVOLEMIA', 'VENTALV'}), {'f': 1.3956970821458365}),
#  (frozenset({'INSUFFANESTH', 'PCWP'}), {'f': 1.1659773847681865}),
#  (frozenset({'ANAPHYLAXIS', 'ERRLOWOUTPUT'}), {'f': 0.25568246739461842}),
#  (frozenset({'SAO2', 'STROKEVOLUME'}), {'f': 1.2296070533491703}),
#  (frozenset({'EXPCO2', 'HISTORY'}), {'f': 0.75294268962085376}),
#  (frozenset({'INTUBATION', 'PVSAT', 'VENTALV'}), {'f': 1.1944602027335778}),
#  (frozenset({'ANAPHYLAXIS', 'VENTALV'}), {'f': 0.95012522370489483}),
#  (frozenset({'PULMEMBOLUS', 'TPR'}), {'f': 1.1449526809578712}),
#  (frozenset({'INSUFFANESTH', 'SAO2'}), {'f': 0.92302032073507534}),
#  (frozenset({'STROKEVOLUME', 'VENTTUBE'}), {'f': 1.4105835668271065}),
#  (frozenset({'ARTCO2', 'EXPCO2', 'VENTALV'}), {'f': 1.4123001787225735}),
#  (frozenset({'DISCONNECT', 'HRBP'}), {'f': 1.0070977620941768}),
#  (frozenset({'ARTCO2', 'HREKG', 'VENTALV'}), {'f': 1.7953393506990778}),
#  (frozenset({'HREKG', 'HRSAT', 'HYPOVOLEMIA'}), {'f': 1.5015139242388011}),
#  (frozenset({'HR', 'HRSAT', 'VENTLUNG'}), {'f': 1.6053218922245851}),
#  (frozenset({'INSUFFANESTH', 'VENTMACH'}), {'f': 0.95144935878433134}),
#  (frozenset({'LVFAILURE', 'STROKEVOLUME'}), {'f': 0.75478645896358776}),
#  (frozenset({'FIO2', 'HR', 'HRSAT'}), {'f': 1.1201419140269004}),
#  (frozenset({'BP', 'STROKEVOLUME'}), {'f': 1.623349059892474}),
#  (frozenset({'HR', 'HRBP', 'STROKEVOLUME'}), {'f': 1.4456898008511414}),
#  (frozenset({'INSUFFANESTH', 'PAP'}), {'f': 0.74108457003570194}),
#  (frozenset({'CO', 'PCWP'}), {'f': 1.6787649478960274}),
#  (frozenset({'ANAPHYLAXIS', 'ERRCAUTER'}), {'f': 0.37483632464828531}),
#  (frozenset({'INSUFFANESTH', 'TPR'}), {'f': 1.4176740227867377}),
#  (frozenset({'CVP', 'STROKEVOLUME'}), {'f': 1.3409292921811224}),
#  (frozenset({'CO', 'MINVOL'}), {'f': 1.73094807787992}),
#  (frozenset({'FIO2', 'INSUFFANESTH'}), {'f': 0.52897470627340826}),
#  (frozenset({'ERRLOWOUTPUT', 'HR', 'HRSAT'}), {'f': 1.1206676539914597}),
#  (frozenset({'STROKEVOLUME', 'TPR'}), {'f': 1.7242388944181395}),
#  (frozenset({'ARTCO2', 'FIO2', 'VENTALV'}), {'f': 1.26123186100469}),
#  (frozenset({'ERRCAUTER', 'HYPOVOLEMIA'}), {'f': 0.82041575363797703}),
#  (frozenset({'MINVOL', 'PCWP', 'VENTALV'}), {'f': 2.0450217702607612}),
#  (frozenset({'HR', 'SHUNT'}), {'f': 0.86052541090780754}),
#  (frozenset({'ERRCAUTER', 'PRESS'}), {'f': 1.4401061934635417}),
#  (frozenset({'ARTCO2', 'CVP', 'VENTALV'}), {'f': 1.827854030039485}),
#  (frozenset({'ARTCO2', 'HISTORY'}), {'f': 0.90305512156532941}),
#  (frozenset({'HR', 'PVSAT'}), {'f': 1.0774416772200412}),
#  (frozenset({'CVP', 'PULMEMBOLUS'}), {'f': 0.82289730270853001}),
#  (frozenset({'FIO2', 'PVSAT', 'SAO2'}), {'f': 0.90734682981197701}),
#  (frozenset({'HRSAT', 'LVFAILURE'}), {'f': 0.95238809888569664}),
#  (frozenset({'HREKG', 'INSUFFANESTH'}), {'f': 1.0845465361602569}),
#  (frozenset({'DISCONNECT', 'PULMEMBOLUS'}), {'f': 0.38051103657909957}),
#  (frozenset({'CATECHOL', 'VENTMACH'}), {'f': 0.93884418567639161}),
#  (frozenset({'HR', 'VENTLUNG'}), {'f': 1.2142244709459851}),
#  (frozenset({'ANAPHYLAXIS', 'INTUBATION'}), {'f': 0.38776825249286795}),
#  (frozenset({'CATECHOL', 'HR', 'HRBP'}), {'f': 0.96943129801888517}),
#  (frozenset({'MINVOL', 'SHUNT', 'VENTALV'}), {'f': 1.4638817565612581}),
#  (frozenset({'HREKG', 'HRSAT', 'KINKEDTUBE'}), {'f': 1.1682167149326539}),
#  (frozenset({'HREKG', 'MINVOL'}), {'f': 1.583391205093992}),
#  (frozenset({'HRSAT', 'TPR'}), {'f': 1.8121800249428388}),
#  (frozenset({'HR', 'HRSAT', 'TPR'}), {'f': 1.9714426307616402}),
#  (frozenset({'CO', 'DISCONNECT'}), {'f': 1.222413055670694}),
#  (frozenset({'VENTMACH', 'VENTTUBE'}), {'f': 1.0435874702115377}),
#  (frozenset({'CVP', 'LVEDVOLUME', 'VENTALV'}), {'f': 2.0019786318112978}),
#  (frozenset({'HR', 'HRBP', 'VENTTUBE'}), {'f': 1.574641751960747}),
#  (frozenset({'PVSAT', 'VENTALV', 'VENTMACH'}), {'f': 1.5061079191181848}),
#  (frozenset({'ARTCO2', 'PCWP', 'VENTALV'}), {'f': 1.898189871708293}),
#  (frozenset({'LVFAILURE', 'VENTTUBE'}), {'f': 0.97483429094303964}),
#  (frozenset({'CVP', 'HYPOVOLEMIA', 'LVEDVOLUME'}), {'f': 1.3232580951354029}),
#  (frozenset({'ANAPHYLAXIS', 'PVSAT', 'SAO2'}), {'f': 0.78210816580407494}),
#  (frozenset({'INSUFFANESTH', 'INTUBATION'}), {'f': 0.66150038105095266}),
#  (frozenset({'BP', 'LVEDVOLUME', 'PCWP'}), {'f': 2.0570194240711186}),
#  (frozenset({'HR', 'HRBP'}), {'f': 0.81100904778942895}),
#  (frozenset({'DISCONNECT', 'ERRLOWOUTPUT'}), {'f': 0.52612986079247903}),
#  (frozenset({'MINVOLSET', 'PVSAT'}), {'f': 0.90437577011644155}),
#  (frozenset({'HREKG', 'HRSAT', 'VENTLUNG'}), {'f': 1.6892488358480273}),
#  (frozenset({'FIO2', 'MINVOL'}), {'f': 1.0436383304515473}),
#  (frozenset({'MINVOL', 'SAO2', 'VENTALV'}), {'f': 1.4283388566588047}),
#  (frozenset({'EXPCO2', 'PVSAT', 'SAO2'}), {'f': 1.2509565954704767}),
#  (frozenset({'CVP', 'HR', 'LVEDVOLUME'}), {'f': 1.6348195070247014}),
#  (frozenset({'SHUNT'}), {'f': 0.3321442135882246}),
#  (frozenset({'FIO2', 'PCWP'}), {'f': 1.0384243479550519}),
#  (frozenset({'LVFAILURE', 'PVSAT', 'VENTALV'}), {'f': 1.2075670399398328}),
#  (frozenset({'HISTORY', 'PVSAT'}), {'f': 0.78141198428501957}),
#  (frozenset({'HISTORY', 'HR'}), {'f': 0.73967968554854524}),
#  (frozenset({'LVEDVOLUME', 'TPR'}), {'f': 1.8803087137176588}),
#  (frozenset({'HRBP', 'HYPOVOLEMIA'}), {'f': 1.1845660567414105}),
#  (frozenset({'CVP', 'LVEDVOLUME'}), {'f': 1.1064999223897884}),
#  (frozenset({'ERRLOWOUTPUT', 'PULMEMBOLUS'}), {'f': 0.2566982510462274}),
#  (frozenset({'ARTCO2', 'KINKEDTUBE'}), {'f': 0.85400413920115992}),
#  (frozenset({'ERRCAUTER', 'VENTALV', 'VENTLUNG'}), {'f': 1.4437629748224241}),
#  (frozenset({'INTUBATION'}), {'f': 0.33325176585773231}),
#  (frozenset({'CVP', 'FIO2'}), {'f': 0.96807894525838944}),
#  (frozenset({'DISCONNECT', 'EXPCO2'}), {'f': 0.86298040771822426}),
#  (frozenset({'EXPCO2', 'VENTTUBE'}), {'f': 1.2693339443817075}),
#  (frozenset({'HRSAT', 'KINKEDTUBE'}), {'f': 0.92022335063272875}),
#  (frozenset({'MINVOLSET'}), {'f': 0.3956269433846985}),
#  (frozenset({'CVP', 'LVEDVOLUME', 'PAP'}), {'f': 1.5191967373866688}),
#  (frozenset({'ERRCAUTER', 'MINVOL'}), {'f': 1.1632141782608438}),
#  (frozenset({'CATECHOL', 'CO'}), {'f': 1.129996786966029}),
#  (frozenset({'SHUNT', 'VENTALV'}), {'f': 1.1744979751321609}),
#  (frozenset({'ERRLOWOUTPUT', 'HREKG', 'HRSAT'}), {'f': 1.2025605887614113}),
#  (frozenset({'CATECHOL', 'HR', 'HRSAT'}), {'f': 1.0779327760180433}),
#  (frozenset({'CVP'}), {'f': 0.76736719824854982}),
#  (frozenset({'HISTORY', 'MINVOLSET'}), {'f': 0.60691866507624948}),
#  (frozenset({'CATECHOL', 'LVFAILURE'}), {'f': 0.52763678541446823}),
#  (frozenset({'ARTCO2', 'HISTORY', 'VENTALV'}), {'f': 1.2718043556516625}),
#  (frozenset({'CATECHOL', 'PAP'}), {'f': 0.74138342195846507}),
#  (frozenset({'SHUNT', 'TPR'}), {'f': 1.4215439846684126}),
#  (frozenset({'FIO2', 'TPR'}), {'f': 1.2901314240063932}),
#  (frozenset({'CATECHOL', 'HRSAT'}), {'f': 0.94637071140942652}),
#  (frozenset({'CATECHOL', 'TPR'}), {'f': 1.3350350898356222}),
#  (frozenset({'PVSAT', 'SAO2', 'SHUNT'}), {'f': 1.0179605223995689}),
#  (frozenset({'DISCONNECT', 'HISTORY'}), {'f': 0.53627366135955556}),
#  (frozenset({'ERRCAUTER', 'PULMEMBOLUS'}), {'f': 0.37585027057264075}),
#  (frozenset({'CVP', 'TPR'}), {'f': 1.8567870600526182}),
#  (frozenset({'ARTCO2', 'ERRLOWOUTPUT', 'VENTALV'}), {'f': 1.2616899859493058}),
#  (frozenset({'CO', 'HR', 'HRSAT'}), {'f': 1.5720070969854667}),
#  (frozenset({'ARTCO2', 'INTUBATION', 'VENTALV'}), {'f': 1.2464411869499967}),
#  (frozenset({'DISCONNECT', 'PAP'}), {'f': 0.73780708087639135}),
#  (frozenset({'ERRLOWOUTPUT', 'VENTALV'}), {'f': 1.0967539669638533}),
#  (frozenset({'ANAPHYLAXIS', 'HYPOVOLEMIA'}), {'f': 0.55463703153693389}),
#  (frozenset({'BP', 'DISCONNECT'}), {'f': 1.384359118082068}),
#  (frozenset({'HREKG', 'HRSAT', 'PCWP'}), {'f': 1.8390664691472727}),
#  (frozenset({'PVSAT', 'SAO2', 'STROKEVOLUME'}), {'f': 1.3623426953117115}),
#  (frozenset({'SAO2', 'VENTALV'}), {'f': 1.1168889473441805}),
#  (frozenset({'ERRLOWOUTPUT', 'MINVOL'}), {'f': 1.044064444365463}),
#  (frozenset({'FIO2', 'LVEDVOLUME', 'PCWP'}), {'f': 1.2121404961981439}),
#  (frozenset({'FIO2', 'HREKG'}), {'f': 0.95703122874185254}),
#  (frozenset({'VENTALV'}), {'f': 0.8956085674440849}),
#  (frozenset({'PAP', 'VENTALV', 'VENTLUNG'}), {'f': 1.536180743882531}),
#  (frozenset({'FIO2', 'SHUNT'}), {'f': 0.53283431029623951}),
#  (frozenset({'ERRLOWOUTPUT', 'PAP'}), {'f': 0.61398539263590457}),
#  (frozenset({'ARTCO2', 'HYPOVOLEMIA', 'VENTALV'}), {'f': 1.5606197805164213}),
#  (frozenset({'CATECHOL', 'LVEDVOLUME'}), {'f': 1.1194560920298233}),
#  (frozenset({'HREKG', 'LVFAILURE'}), {'f': 0.95534697863408891}),
#  (frozenset({'HREKG', 'HRSAT', 'VENTTUBE'}), {'f': 1.766196009507917}),
#  (frozenset({'CATECHOL', 'HYPOVOLEMIA'}), {'f': 0.82867255369851089}),
#  (frozenset({'INTUBATION', 'VENTTUBE'}), {'f': 1.1090026079576254}),
#  (frozenset({'ARTCO2', 'VENTALV', 'VENTLUNG'}), {'f': 1.2883568744055349}),
#  (frozenset({'CVP', 'LVEDVOLUME', 'PULMEMBOLUS'}), {'f': 1.1620121457264532}),
#  (frozenset({'INSUFFANESTH', 'PULMEMBOLUS'}), {'f': 0.38379571239068472}),
#  (frozenset({'SAO2', 'TPR'}), {'f': 1.6841682116114871}),
#  (frozenset({'CO', 'HISTORY'}), {'f': 1.0696653982513022}),
#  (frozenset({'ARTCO2', 'LVEDVOLUME', 'VENTALV'}), {'f': 1.8513822322585447}),
#  (frozenset({'PULMEMBOLUS', 'STROKEVOLUME'}), {'f': 0.69033690626533295}),
#  (frozenset({'HRBP', 'KINKEDTUBE'}), {'f': 0.85127150594575685}),
#  (frozenset({'SAO2'}), {'f': 0.59479033938566761}),
#  (frozenset({'MINVOL', 'PRESS', 'VENTALV'}), {'f': 2.2741811979982063}),
#  (frozenset({'HR', 'HRSAT', 'SAO2'}), {'f': 1.494437804080156}),
#  (frozenset({'FIO2', 'STROKEVOLUME'}), {'f': 0.83553755176329059}),
#  (frozenset({'HISTORY', 'HRSAT'}), {'f': 0.9646075881578382}),
#  (frozenset({'HRBP', 'PVSAT', 'SAO2'}), {'f': 1.3932617778165282}),
#  (frozenset({'HYPOVOLEMIA', 'MINVOL', 'VENTALV'}), {'f': 1.7074694042677134}),
#  (frozenset({'HR', 'HRSAT', 'SHUNT'}), {'f': 1.251657746926967}),
#  (frozenset({'ARTCO2', 'PRESS', 'VENTALV'}), {'f': 2.1344896943802039}),
#  (frozenset({'INSUFFANESTH', 'MINVOL'}), {'f': 1.1711421417654595}),
#  (frozenset({'ANAPHYLAXIS', 'KINKEDTUBE'}), {'f': 0.22150387173319697}),
#  (frozenset({'LVFAILURE', 'TPR'}), {'f': 1.2884946120226737}),
#  (frozenset({'ARTCO2', 'KINKEDTUBE', 'VENTALV'}), {'f': 1.2210195689418508}),
#  (frozenset({'MINVOLSET', 'VENTLUNG'}), {'f': 1.0256566446935209}),
#  (frozenset({'CVP', 'HREKG'}), {'f': 1.5236436210705917}),
#  (frozenset({'HR', 'HRSAT', 'LVFAILURE'}), {'f': 1.1185488263445673}),
#  (frozenset({'DISCONNECT', 'PVSAT'}), {'f': 0.85997228731559505}),
#  (frozenset({'HR', 'HRBP', 'SHUNT'}), {'f': 1.1431253358503035}),
#  (frozenset({'HR', 'HRBP', 'PAP'}), {'f': 1.2237149768627482}),
#  (frozenset({'CVP', 'PVSAT', 'VENTALV'}), {'f': 1.7757813788068562}),
#  (frozenset({'CVP', 'LVEDVOLUME', 'PRESS'}), {'f': 2.2262044607067089}),
#  (frozenset({'EXPCO2', 'MINVOL'}), {'f': 1.3153728261064432}),
#  (frozenset({'BP', 'HR'}), {'f': 1.5596746486623407}),
#  (frozenset({'DISCONNECT', 'MINVOL'}), {'f': 1.1222014237165645}),
#  (frozenset({'BP', 'PVSAT'}), {'f': 1.6273354450205071}),
#  (frozenset({'HR', 'PAP'}), {'f': 0.9411633192859038}),
#  (frozenset({'ANAPHYLAXIS', 'HREKG'}), {'f': 0.81076556290331914}),
#  (frozenset({'CVP', 'MINVOL', 'VENTALV'}), {'f': 1.9746561469838149}),
#  (frozenset({'MINVOL', 'TPR', 'VENTALV'}), {'f': 2.2966746922213117}),
#  (frozenset({'FIO2', 'VENTTUBE'}), {'f': 0.97649222174195094}),
#  (frozenset({'HRBP', 'MINVOL', 'VENTALV'}), {'f': 1.8703559615351852}),
#  (frozenset({'HREKG', 'HRSAT', 'INSUFFANESTH'}), {'f': 1.3296081381797358}),
#  (frozenset({'ARTCO2', 'PVSAT'}), {'f': 0.88216050723405681}),
#  (frozenset({'HISTORY', 'LVEDVOLUME', 'PCWP'}), {'f': 1.1272636106738667}),
#  (frozenset({'ERRCAUTER', 'VENTALV'}), {'f': 1.2158966148147079}),
#  (frozenset({'INTUBATION', 'VENTLUNG'}), {'f': 1.0211389501794228}),
#  (frozenset({'LVFAILURE', 'PCWP'}), {'f': 0.9372179791319023}),
#  (frozenset({'HYPOVOLEMIA', 'PAP'}), {'f': 0.91292617134907661}),
#  (frozenset({'CATECHOL', 'VENTALV'}), {'f': 1.1718827166730654}),
#  (frozenset({'ERRCAUTER', 'HISTORY'}), {'f': 0.53156610342770938}),
#  (frozenset({'HISTORY', 'MINVOL', 'VENTALV'}), {'f': 1.4186391786361798}),
#  (frozenset({'HR', 'HRBP', 'MINVOL'}), {'f': 1.6346422447026761}),
#  (frozenset({'CATECHOL', 'VENTALV', 'VENTLUNG'}), {'f': 1.3997383325181016}),
#  (frozenset({'HREKG'}), {'f': 0.75632288738776787}),
#  (frozenset({'ARTCO2', 'HYPOVOLEMIA'}), {'f': 1.1918555657988794}),
#  (frozenset({'ERRCAUTER', 'MINVOLSET'}), {'f': 0.71592011834779112}),
#  (frozenset({'KINKEDTUBE', 'LVFAILURE'}), {'f': 0.36609424878508046}),
#  (frozenset({'LVEDVOLUME', 'PCWP', 'PRESS'}), {'f': 2.1311750056552023}),
#  (frozenset({'CO', 'INTUBATION'}), {'f': 1.231871472176596}),
#  (frozenset({'EXPCO2', 'MINVOL', 'VENTALV'}), {'f': 1.5923811904740846}),
#  (frozenset({'LVFAILURE', 'PVSAT', 'SAO2'}), {'f': 0.92663456089580576}),
#  (frozenset({'HISTORY', 'VENTMACH'}), {'f': 0.83450539792750367}),
#  (frozenset({'PVSAT', 'SAO2', 'TPR'}), {'f': 1.8169409433922987}),
#  (frozenset({'HR', 'HRSAT', 'KINKEDTUBE'}), {'f': 1.0863348743165291}),
#  (frozenset({'INSUFFANESTH', 'PRESS'}), {'f': 1.448033423099806}),
#  (frozenset({'ERRLOWOUTPUT', 'TPR'}), {'f': 1.2905709722885008}),
#  (frozenset({'CO', 'LVEDVOLUME', 'PCWP'}), {'f': 1.8383564589013304}),
#  (frozenset({'LVEDVOLUME', 'PCWP', 'SHUNT'}), {'f': 1.3436220484109347}),
#  (frozenset({'HREKG', 'VENTLUNG'}), {'f': 1.4453678316586611}),
#  (frozenset({'KINKEDTUBE', 'TPR'}), {'f': 1.2564247402898285}),
#  (frozenset({'ERRLOWOUTPUT', 'VENTMACH'}), {'f': 0.82435218884588479}),
#  (frozenset({'CATECHOL'}), {'f': 0.32856258284547102}),
#  (frozenset({'KINKEDTUBE', 'PVSAT', 'VENTALV'}), {'f': 1.1690150705537605}),
#  (frozenset({'HYPOVOLEMIA', 'MINVOL'}), {'f': 1.3430339262205198}),
#  (frozenset({'FIO2'}), {'f': 0.2007176819971099}),
#  (frozenset({'MINVOL', 'PRESS'}), {'f': 1.9233400568238792}),
#  (frozenset({'ARTCO2', 'PVSAT', 'VENTALV'}), {'f': 1.173414140469915}),
#  (frozenset({'PAP'}), {'f': 0.4128340264762641}),
#  (frozenset({'ARTCO2', 'SAO2', 'VENTALV'}), {'f': 1.2817535664653352}),
#  (frozenset({'HISTORY', 'HREKG', 'HRSAT'}), {'f': 1.2126360631994948}),
#  (frozenset({'FIO2', 'HRSAT'}), {'f': 0.9540563379875231}),
#  (frozenset({'LVEDVOLUME', 'PRESS'}), {'f': 1.910657232766817}),
#  ...]

# %%
data.columns
# Out:
# Index([u'ANAPHYLAXIS', u'DISCONNECT', u'TPR', u'INSUFFANESTH', u'LVFAILURE',
#        u'HISTORY', u'HYPOVOLEMIA', u'STROKEVOLUME', u'INTUBATION',
#        u'LVEDVOLUME', u'PCWP', u'FIO2', u'ERRLOWOUTPUT', u'MINVOLSET',
#        u'VENTMACH', u'VENTTUBE', u'PULMEMBOLUS', u'SHUNT', u'ERRCAUTER',
#        u'KINKEDTUBE', u'PRESS', u'CVP', u'VENTLUNG', u'MINVOL', u'VENTALV',
#        u'ARTCO2', u'PVSAT', u'SAO2', u'CATECHOL', u'HR', u'HRBP', u'CO', u'BP',
#        u'HRSAT', u'HREKG', u'EXPCO2', u'PAP'],
#       dtype='object')

# %%
vec = [False] * len(data.columns)
#vec[list(data.columns).index('CVP')] = True
vec[list(data.columns).index('LVEDVOLUME')] = True
vec[8] = True
vec[9] = True
vec[11] = True
vec[20] = True

# %%
# %%time
gs.fscore.lower_bound(list(data.columns).index('CVP'), vec)
# Out:
# CPU times: user 12 ms, sys: 0 ns, total: 12 ms
# Wall time: 9.14 ms
# -6428.9801372677375

# %%
gs.fscore.upper_bound(list(data.columns).index('CVP'), vec)
# Out:
# 94625.472491508262

# %%
# %%time
gs.fscore(list(data.columns).index('CVP'), vec)
# Out:
# CPU times: user 152 ms, sys: 0 ns, total: 152 ms
# Wall time: 150 ms
# 44146.487426811793

# %%
len(gs.fscore.mi_estimator.entropy_estimator.sg.nodes())
# Out:
# 1631
